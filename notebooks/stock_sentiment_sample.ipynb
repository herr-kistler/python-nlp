# %% [markdown]
# 21 Dec. 2017
#
# Stock Market Sentiment Analysis (sample)
#
# ** Using CNBC.com data (stock-specific news articles), create corpus and analyze the current overall sentiment rating for a specifc stock.**

# %%
import nltk
import pandas as pd

df = pd.DataFrame(columns = ['Sentences', 'Words', 'POS-Tags', 'Chunk-Trees'])

sent_list = []
word_list = []
pos_list = []
chunk_list = []

# COROUTINE TOKENIZING PIPELINE 
# TO INCREASE PRODUCTIVITY AND EFFICIENCY IN PREPARING AN ANALYZABLE CORPUS OF VARIOUS LEXICAL FORMATS

# EACH "PRINTER()"-COROUTINE APPENDS (LINE BY LINE) THE RESULTS TO ITS APPROPRIATE CATEGORIZED LIST
# AND ALSO ADDS THE RESULTS TO THE APPROPRIATE DATAFRAME COLUMN

def coroutine(func):
    def start(*args, **kwargs):
        cr = func(*args, **kwargs)
        cr.__next__()
        return cr
    return start

def source(texts, targets):
    for text in texts:
        for t in targets:
            t.send(text)
            
@coroutine
def sent_tokenize_pipeline(targets):
    while True:
        text = (yield)
        sentences = nltk.sent_tokenize(text)
        for sentence in sentences:
            for target in targets:
                target.send(sentence)
 
@coroutine
def word_tokenize_pipeline(targets):
    while True:
        sentence = (yield)
        words = nltk.word_tokenize(sentence)
        for target in targets:
            target.send(words)
 
@coroutine
def pos_tag_pipeline(targets):
    while True:
        words = (yield)
        tagged_words = nltk.pos_tag(words)
 
        for target in targets:
            target.send(tagged_words)
 
@coroutine
def ne_chunk_pipeline(targets):
    while True:
        tagged_words = (yield)
        ner_tagged = nltk.ne_chunk(tagged_words)
 
        for target in targets:
            target.send(ner_tagged)
        
@coroutine
def chunk_printer():
    while True:
        line = (yield)
        print(line)
        chunk_list.append(line)
        df.append({'Chunk-Trees': line}, ignore_index=True)
        
@coroutine
def sent_printer():
    while True:
        line = (yield)
        print(line)
        sent_list.append(line)
        df.append({'Sentences': line}, ignore_index=True)
        
@coroutine
def word_printer():
    while True:
        line = (yield)
        print(line)
        word_list.append(line)
        df.append({'Words': line}, ignore_index=True)
        
@coroutine
def pos_printer():
    while True:
        line = (yield)
        print(line)
        pos_list.append(line)
        df.append({'POS-Tags': line}, ignore_index=True)
        
        
@coroutine
def filter_short(min_len, targets):
    while True:
        words = (yield)
        if len(words) < min_len:
            continue
        for target in targets:
            target.send(words)

# %%
import requests
import lxml.html
import urllib
import nltk
import re
from urllib.request import urlopen
from bs4 import BeautifulSoup

#INSERT ANY STOCK SYMBOL TO COMPILE CURRENT NEWS CORPUS AND RETURN THE SENTIMENT ANALYSIS (POLARITY RATING) FOR EACH ARTICLE
symbol = '.DJI'
more_symbols = ['.SPX', '.IXIC', '.RUT', '.VIX', 'AAPL', 'STZ'] 
main_url = 'https://www.cnbc.com/quotes/?symbol=' + symbol + '&tab=news'
texts = []

#PULL AND FORMAT FROM AN HTML LINK
dom = lxml.html.fromstring(requests.get(main_url).content)

#COLLECT ONLY CURRENT NEWS ARTICLES ON THE STOCK'S PROFILE
article_links = [x for x in dom.xpath('//a/@href') if '//' in x and 'cnbc.com/201' in x]
print(article_links)

for link in article_links:
    html = urllib.request.urlopen(link).read()
    soup = BeautifulSoup(html, "lxml")
    
    # kill all script and style elements
    for script in soup(["script", "style"]):
        script.extract()    # rip it out
    
    text = soup.find("div", id="article_body").text.strip().encode("utf-8")
    # id="article_deck" for getting article summary header
    text = text.decode("utf-8")
    # break into lines and remove leading and trailing space on each
    lines = (line.strip() for line in text.splitlines())
    # break multi-headlines into a line each
    chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
    # drop blank lines
    text = '\n'.join(chunk for chunk in chunks if chunk)
    
    texts.append(text)
   

# CHECK THE CLEAN AND PARSED LIST OF ARTICLE TEXT:
# print(texts)


# PIPELINE IMPLEMENTATION TO PREPARE DATA
chunked_corpus = source(texts, targets=[
    sent_tokenize_pipeline(targets=[
        word_tokenize_pipeline(targets=[
            filter_short(3, targets=[ # FILTERING OUT SENTENCES LESS THAN 3 WORDS
                pos_tag_pipeline(targets=[
                    ne_chunk_pipeline(targets=[chunk_printer()]),
                ])
            ])
        ])
    ])
])

sentences = source(texts, targets=[
    sent_tokenize_pipeline(targets=[sent_printer()])])

words = source(texts, targets=[
    sent_tokenize_pipeline(targets=[
        word_tokenize_pipeline(targets=[word_printer()])])])
                               
pos_tags = source(texts, targets=[
    sent_tokenize_pipeline(targets=[
        word_tokenize_pipeline(targets=[
            filter_short(3, targets=[
                pos_tag_pipeline(targets=[pos_printer()])])])])])

#df and lists now available
# Out:
# ['https://www.cnbc.com/2017/11/08/healthy-returns.html', 'https://www.cnbc.com/2018/01/12/us-stocks-earnings-season-dow-jp-morgan.html', 'https://www.cnbc.com/2018/01/12/us-stock-futures-dow-fed-speeches-earnings-bonds-data-and-politics-on-the-agenda.html', 'https://www.cnbc.com/2018/01/11/theres-going-to-be-a-made-in-america-stock-boom-this-year-jefferies.html']
# (S
#   ABOUT/IN
#   (ORGANIZATION SPEAKERS/NNP)
#   AGENDA/NNP
#   ADVISORY/NNP
#   (ORGANIZATION BOARD/NNP)
#   VENUE/NNP
#   SPONSORS/NNP
#   CONTACT/NNP
#   About/IN
#   How/NNP
#   innovators/NNS
#   and/CC
#   investors/NNS
#   are/VBP
#   working/VBG
#   with/IN
#   patients/NNS
#   and/CC
#   providers/NNS
#   to/TO
#   develop/VB
#   dynamic/JJ
#   new/JJ
#   solutions/NNS
#   and/CC
#   create/VB
#   healthy/JJ
#   returns/NNS
#   ./.)
# (S
#   (ORGANIZATION CNBC/NNP)
#   presents/VBZ
#   a/DT
#   one-day/JJ
#   event/NN
#   at/IN
#   (ORGANIZATION NYC/NNP)
#   ’/NNP
#   s/VBD
#   (PERSON Roosevelt/NNP Hotel/NNP)
#   that/WDT
#   brings/VBZ
#   together/RB
#   top/JJ
#   health/NN
#   care/NN
#   investors/NNS
#   ,/,
#   (ORGANIZATION CEOs/NNP)
#   and/CC
#   technologists/NNS
#   to/TO
#   explore/VB
#   the/DT
#   innovations/NNS
#   that/WDT
#   will/MD
#   drive/VB
#   better/JJR
#   outcomes/NNS
#   ,/,
#   financially/RB
#   and/CC
#   clinically/RB
#   ./.)
# (S
#   Every/DT
#   health/NN
#   care/NN
#   company/NN
#   seeks/VBZ
#   to/TO
#   scale/VB
#   the/DT
#   best/JJS
#   technology/NN
#   and/CC
#   develop/VB
#   profitable/JJ
#   ways/NNS
#   to/TO
#   cover/VB
#   the/DT
#   massive/JJ
#   cost/NN
#   of/IN
#   research/NN
#   and/CC
#   development/NN
#   ,/,
#   investors/NNS
#   are/VBP
#   looking/VBG
#   for/IN
#   actionable/JJ
#   intelligence/NN
#   on/IN
#   who/WP
#   ’/VBP
#   s/NN
#   breaking/NN
#   through/IN
#   ,/,
#   and/CC
#   patients/NNS
#   are/VBP
#   hungry/JJ
#   for/IN
#   affordable/JJ
#   and/CC
#   effective/JJ
#   care/NN
#   ./.)
# (S
#   (PERSON Healthy/JJ)
#   (ORGANIZATION Returns/NNP)
#   is/VBZ
#   a/DT
#   convening/NN
#   of/IN
#   leaders/NNS
#   who/WP
#   are/VBP
#   improving/VBG
#   patient/JJ
#   outcomes/NNS
#   ,/,
#   maximizing/VBG
#   innovation/NN
#   ,/,
#   building/VBG
#   great/JJ
#   new/JJ
#   companies/NNS
#   and/CC
#   reinventing/VBG
#   incumbents/NNS
#   ./.)
# (S
#   Led/VBN
#   by/IN
#   (ORGANIZATION CNBC/NNP)
#   ’/NNP
#   s/NN
#   anchors/NNS
#   and/CC
#   reporters/NNS
#   and/CC
#   with/IN
#   input/NN
#   from/IN
#   a/DT
#   world-class/JJ
#   advisory/JJ
#   board/NN
#   ,/,
#   (PERSON Healthy/NNP Returns/NNP)
#   will/MD
#   hone/VB
#   in/IN
#   on/IN
#   groundbreaking/VBG
#   ideas/NNS
#   that/WDT
#   will/MD
#   transform/VB
#   the/DT
#   health/NN
#   care/NN
#   industry/NN
#   ,/,
#   cutting/VBG
#   through/IN
#   the/DT
#   noise/NN
#   and/CC
#   weeding/VBG
#   out/RP
#   the/DT
#   ``/``
#   sales/NNS
#   pitch/NN
#   ./.
#   ''/'')
# (S
#   Attendees/NNS
#   should/MD
#   expect/VB
#   to/TO
#   walk/VB
#   away/RB
#   with/IN
#   smart/JJ
#   strategies/NNS
#   and/CC
#   actionable/JJ
#   insights/NNS
#   from/IN
#   people/NNS
#   who/WP
#   are/VBP
#   shaping/VBG
#   the/DT
#   industry/NN
#   ,/,
#   including/VBG
#   :/:
#   •/JJ
#   Investment/NNP
#   ideas/NNS
#   and/CC
#   intelligence/NN
#   from/IN
#   the/DT
#   biggest/JJS
#   and/CC
#   best/JJS
#   health/NN
#   care/NN
#   hedge/NN
#   funds/NNS
#   ,/,
#   venture/NN
#   capitalists/NNS
#   and/CC
#   portfolio/NN
#   managers/NNS
#   ./.)
# (S
#   •/JJ
#   Strategic/NNP
#   perspective/NN
#   from/IN
#   top/JJ
#   health/NN
#   care/NN
#   (ORGANIZATION CEOs/NNP)
#   ./.)
# (S
#   •/VB
#   An/DT
#   early/JJ
#   ,/,
#   inside/JJ
#   look/NN
#   at/IN
#   groundbreaking/NN
#   ,/,
#   transformative/JJ
#   innovations/NNS
#   ./.)
# (S
#   •/NN
#   (PERSON Unique/NNP)
#   networking/NN
#   opportunities/NNS
#   to/TO
#   connect/VB
#   with/IN
#   leaders/NNS
#   in/IN
#   multiple/JJ
#   disciplines/NNS
#   –/JJ
#   investors/NNS
#   ,/,
#   executives/NNS
#   ,/,
#   entrepreneurs/NNS
#   and/CC
#   innovators/NNS
#   ./.)
# (S
#   Who/WP
#   should/MD
#   attend/VB
#   :/:
#   Health/NNP
#   care/NN
#   investors/NNS
#   ,/,
#   (ORGANIZATION VCs/NNP)
#   ,/,
#   C-Suite/NNP
#   executives/NNS
#   from/IN
#   the/DT
#   biotech/NN
#   ,/,
#   pharma/NN
#   ,/,
#   health/NN
#   care/NN
#   and/CC
#   life/NN
#   sciences/NNS
#   industries/NNS
#   ,/,
#   health/NN
#   care/NN
#   IT/NNP
#   BDMs/NNP
#   ./.)
# (S
#   Speakers/NNS
#   More/JJR
#   speakers/NNS
#   will/MD
#   be/VB
#   announced/VBN
#   soon/RB
#   ./.)
# (S
#   Tap/NNP
#   or/CC
#   click/VB
#   a/DT
#   card/NN
#   to/TO
#   reveal/VB
#   more/JJR
#   information/NN
#   :/:
#   (PERSON Amy/NNP Abernethy/NNP)
#   M.D./NNP
#   ,/,
#   (ORGANIZATION PhD/NNP)
#   ,/,
#   serves/VBZ
#   as/IN
#   chief/JJ
#   medical/JJ
#   officer/NN
#   ,/,
#   chief/JJ
#   scientific/JJ
#   officer/NN
#   and/CC
#   senior/JJ
#   vice/NN
#   president/NN
#   ,/,
#   oncology/NN
#   of/IN
#   (PERSON Flatiron/NNP Health/NNP)
#   ./.)
# (S
#   (ORGANIZATION READ/NNP)
#   (ORGANIZATION MORE/NNP Amy/NNP Abernethy/NNP)
#   M.D./NNP
#   ,/,
#   (ORGANIZATION PhDChief/NNP Medical/NNP Officer/NNP)
#   ,/,
#   Chief/NNP
#   (PERSON Scientific/NNP Officer/NNP)
#   ,/,
#   (ORGANIZATION Senior/NNP)
#   Vice/NNP
#   President/NNP
#   ,/,
#   (PERSON Flatiron/NNP Health/NNP)
#   (PERSON Bill/NNP George/NNP)
#   is/VBZ
#   an/DT
#   (GPE American/JJ)
#   businessman/NN
#   and/CC
#   academic/JJ
#   ./.)
# (S
#   He/PRP
#   is/VBZ
#   professor/NN
#   of/IN
#   (ORGANIZATION Management/NNP Practice/NNP)
#   and/CC
#   a/DT
#   (PERSON Henry/NNP B./NNP Arthur/NNP Fellow/NNP)
#   of/IN
#   (GPE Ethics/NNP)
#   ,/,
#   at/IN
#   (ORGANIZATION Harvard/NNP Business/NNP School/NNP)
#   ./.)
# (S
#   (ORGANIZATION READ/NNP)
#   (ORGANIZATION MORE/NNP)
#   (PERSON Bill/NNP GeorgeSenior/NNP Fellow/NNP)
#   ,/,
#   (PERSON Harvard/NNP Business/NNP School/NNP)
#   and/CC
#   (ORGANIZATION Former/NNP)
#   Chairman/NNP
#   and/CC
#   (ORGANIZATION CEO/NNP)
#   ,/,
#   (PERSON Medtronic/NNP)
#   Dr./NNP
#   Gottlieb/NNP
#   is/VBZ
#   the/DT
#   23rd/JJ
#   commissioner/NN
#   of/IN
#   the/DT
#   (ORGANIZATION Food/NNP)
#   and/CC
#   (PERSON Drug/NNP Administration/NNP)
#   ./.)
# (S
#   (ORGANIZATION READ/NNP)
#   (ORGANIZATION MORE/NNP Scott/NNP Gottlieb/NNP)
#   ,/,
#   M.D.Commissioner/NNP
#   of/IN
#   (GPE Food/NNP)
#   and/CC
#   (PERSON Drugs/NNP)
#   ,/,
#   (GPE U.S./NNP)
#   (ORGANIZATION FDA/NNP Fred/NNP Hassan/NNP)
#   is/VBZ
#   a/DT
#   special/JJ
#   limited/JJ
#   partner/NN
#   and/CC
#   managing/VBG
#   director/NN
#   with/IN
#   the/DT
#   private/JJ
#   equity/NN
#   firm/NN
#   ,/,
#   (PERSON Warburg/NNP Pincus/NNP)
#   and/CC
#   chairman/NN
#   of/IN
#   (ORGANIZATION Caret/NNP Group/NNP)
#   ./.)
# (S
#   (ORGANIZATION READ/NNP)
#   (ORGANIZATION MORE/NNP Fred/NNP)
#   HassanSpecial/NNP
#   Limited/NNP
#   (PERSON Partner/NNP)
#   ,/,
#   (PERSON Warburg/NNP Pincus/NNP)
#   and/CC
#   (PERSON Chairman/NNP)
#   ,/,
#   (PERSON Caret/NNP Group/NNP Leonard/NNP S./NNP Schleifer/NNP)
#   ,/,
#   M.D./NNP
#   ,/,
#   (ORGANIZATION PhD/NNP)
#   ,/,
#   is/VBZ
#   the/DT
#   founder/NN
#   ,/,
#   president/NN
#   and/CC
#   chief/JJ
#   executive/JJ
#   officer/NN
#   of/IN
#   (PERSON Regeneron/NNP Pharmaceuticals/NNP)
#   ./.)
# (S
#   (ORGANIZATION READ/NNP)
#   (ORGANIZATION MORE/NNP Leonard/NNP)
#   S./NNP
#   Schleifer/NNP
#   ,/,
#   M.D./NNP
#   ,/,
#   (ORGANIZATION PhD/NNP Founder/NNP)
#   ,/,
#   President/NNP
#   and/CC
#   (ORGANIZATION CEO/NNP)
#   ,/,
#   (PERSON Regeneron/NNP Pharmaceuticals/NNP Agenda/NNP Agenda/NNP)
#   coming/VBG
#   soon/RB
#   (PERSON Advisory/NNP Board/NNP Tap/NNP)
#   or/CC
#   click/VB
#   a/DT
#   card/NN
#   to/TO
#   reveal/VB
#   more/JJR
#   information/NN
#   :/:
#   (PERSON Amy/NNP Abernethy/NNP)
#   M.D./NNP
#   ,/,
#   (ORGANIZATION PhD/NNP)
#   ,/,
#   serves/VBZ
#   as/IN
#   chief/JJ
#   medical/JJ
#   officer/NN
#   ,/,
#   chief/JJ
#   scientific/JJ
#   officer/NN
#   and/CC
#   senior/JJ
#   vice/NN
#   president/NN
#   ,/,
#   oncology/NN
#   of/IN
#   (PERSON Flatiron/NNP Health/NNP)
#   ./.)
# (S
#   (ORGANIZATION READ/NNP)
#   (ORGANIZATION MORE/NNP Amy/NNP Abernethy/NNP)
#   M.D./NNP
#   ,/,
#   (ORGANIZATION PhD/NNP)
#   Chief/NNP
#   (PERSON Medical/NNP Officer/NNP)
#   ,/,
#   Chief/NNP
#   (PERSON Scientific/NNP Officer/NNP)
#   ,/,
#   (ORGANIZATION Senior/NNP)
#   Vice/NNP
#   President/NNP
#   ,/,
#   (PERSON Flatiron/NNP Health/NNP)
#   Dr./NNP
#   Coles/NNP
#   is/VBZ
#   the/DT
#   chairman/NN
#   and/CC
#   chief/JJ
#   executive/JJ
#   officer/NN
#   of/IN
#   (ORGANIZATION Yumanity/NNP Therapeutics/NNP)
#   ,/,
#   a/DT
#   biotechnology/NN
#   company/NN
#   ./.)
# (S
#   He/PRP
#   also/RB
#   serves/VBZ
#   as/IN
#   chairman/NN
#   and/CC
#   chief/JJ
#   executive/JJ
#   officer/NN
#   of/IN
#   (ORGANIZATION TRATE/NNP Enterprises/NNP)
#   LLC/NNP
#   ./.)
# (S
#   (ORGANIZATION READ/NNP)
#   (ORGANIZATION MORE/NNP Tony/NNP Coles/NNP)
#   ,/,
#   M.D/NNP
#   ./.)
# (S
#   Chairman/NNP
#   and/CC
#   (ORGANIZATION CEO/NNP)
#   ,/,
#   (ORGANIZATION Yumanity/NNP)
#   Therapeutics/NNP
#   Dr./NNP
#   Cosgrove/NNP
#   is/VBZ
#   president/NN
#   and/CC
#   chief/JJ
#   executive/JJ
#   officer/NN
#   of/IN
#   (GPE Cleveland/NNP Clinic/NNP)
#   ,/,
#   presiding/VBG
#   over/IN
#   an/DT
#   $/$
#   8/CD
#   billion/CD
#   health-care/JJ
#   system/NN
#   ./.)
# (S
#   (ORGANIZATION READ/NNP)
#   (ORGANIZATION MORE/NNP Delos/NNP)
#   M./NNP
#   Cosgrove/NNP
#   ,/,
#   M.D/NNP
#   ./.)
# (S
#   President/NNP
#   and/CC
#   (ORGANIZATION CEO/NNP)
#   ,/,
#   (PERSON Cleveland/NNP Clinic/NNP)
#   Dr./NNP
#   (PERSON Kenneth/NNP L./NNP Davis/NNP)
#   ,/,
#   is/VBZ
#   president/NN
#   and/CC
#   chief/JJ
#   executive/JJ
#   officer/NN
#   of/IN
#   the/DT
#   (ORGANIZATION Mount/NNP Sinai/NNP Health/NNP System/NNP)
#   in/IN
#   (GPE New/NNP York/NNP City/NNP)
#   ,/,
#   one/CD
#   of/IN
#   the/DT
#   nation/NN
#   's/POS
#   largest/JJS
#   integrated/VBN
#   health/NN
#   systems/NNS
#   ./.)
# (S
#   (ORGANIZATION READ/NNP)
#   (ORGANIZATION MORE/NNP Kenneth/NNP Davis/NNP)
#   ,/,
#   M.D/NNP
#   ./.)
# (S
#   President/NNP
#   and/CC
#   (ORGANIZATION CEO/NNP)
#   ,/,
#   (PERSON Mount/NNP Sinai/NNP Health/NNP System/NNP)
#   Dr./NNP
#   Sue/NNP
#   Desmond-Hellmann/NNP
#   is/VBZ
#   a/DT
#   physician/NN
#   ,/,
#   scientist/NN
#   and/CC
#   philanthropist/NN
#   and/CC
#   is/VBZ
#   currently/RB
#   the/DT
#   chief/JJ
#   executive/JJ
#   officer/NN
#   of/IN
#   the/DT
#   (ORGANIZATION Bill/NNP)
#   &/CC
#   (PERSON Melinda/NNP Gates/NNP)
#   Foundation/NNP
#   ./.)
# (S
#   (ORGANIZATION READ/NNP)
#   (ORGANIZATION MORE/NNP Sue/NNP)
#   Desmond-Hellmann/NNP
#   CEO/NNP
#   ,/,
#   (PERSON Bill/NNP)
#   &/CC
#   (PERSON Melinda/NNP Gates/NNP)
#   Foundation/NNP
#   Esther/NNP
#   (PERSON Dyson/NNP)
#   is/VBZ
#   chairman/NN
#   of/IN
#   (ORGANIZATION EDventure/NNP Holdings/NNPS)
#   ./.)
# (S
#   Her/PRP$
#   primary/JJ
#   activity/NN
#   is/VBZ
#   investing/VBG
#   in/IN
#   and/CC
#   nurturing/VBG
#   start-ups/NNS
#   ,/,
#   with/IN
#   a/DT
#   recent/JJ
#   focus/NN
#   on/IN
#   health/NN
#   care/NN
#   ,/,
#   human/JJ
#   capital/NN
#   and/CC
#   aerospace/NN
#   ./.)
# (S
#   (ORGANIZATION READ/NNP)
#   (ORGANIZATION MORE/NNP Esther/NNP Dyson/NNP)
#   Chairman/NNP
#   ,/,
#   (ORGANIZATION EDventure/NNP Holdings/NNP Bill/NNP George/NNP)
#   is/VBZ
#   an/DT
#   (GPE American/JJ)
#   businessman/NN
#   and/CC
#   academic/JJ
#   ./.)
# (S
#   He/PRP
#   is/VBZ
#   professor/NN
#   of/IN
#   (ORGANIZATION Management/NNP Practice/NNP)
#   and/CC
#   a/DT
#   (PERSON Henry/NNP B./NNP Arthur/NNP Fellow/NNP)
#   of/IN
#   (GPE Ethics/NNP)
#   at/IN
#   (ORGANIZATION Harvard/NNP Business/NNP School/NNP)
#   ./.)
# (S
#   (ORGANIZATION READ/NNP)
#   (ORGANIZATION MORE/NNP)
#   (PERSON Bill/NNP GeorgeSenior/NNP Fellow/NNP)
#   ,/,
#   (PERSON Harvard/NNP Business/NNP School/NNP)
#   and/CC
#   (ORGANIZATION Former/NNP)
#   Chairman/NNP
#   and/CC
#   (ORGANIZATION CEO/NNP)
#   ,/,
#   (PERSON Medtronic/NNP)
#   Dr./NNP
#   (PERSON Laurie/NNP H./NNP Glimcher/NNP)
#   ,/,
#   president/NN
#   and/CC
#   chief/JJ
#   executive/JJ
#   officer/NN
#   of/IN
#   Dana-Farber/NNP
#   Cancer/NNP
#   Institute/NNP
#   ,/,
#   is/VBZ
#   also/RB
#   chief/JJ
#   executive/JJ
#   officer/NN
#   of/IN
#   Dana-Farber/Partners/NNP
#   CancerCare/NNP
#   ./.)
# (S
#   (ORGANIZATION READ/NNP)
#   (ORGANIZATION MORE/NNP Laurie/NNP Glimcher/NNP)
#   ,/,
#   M.D/NNP
#   ./.)
# (S
#   President/NNP
#   and/CC
#   (ORGANIZATION CEO/NNP)
#   ,/,
#   Dana-Farber/NNP
#   Cancer/NNP
#   Institute/NNP
#   (PERSON Fred/NNP Hassan/NNP)
#   is/VBZ
#   a/DT
#   special/JJ
#   limited/JJ
#   partner/NN
#   and/CC
#   managing/VBG
#   director/NN
#   with/IN
#   the/DT
#   private/JJ
#   equity/NN
#   firm/NN
#   ,/,
#   (PERSON Warburg/NNP Pincus/NNP)
#   and/CC
#   chairman/NN
#   of/IN
#   (ORGANIZATION Caret/NNP Group/NNP)
#   ./.)
# (S
#   (ORGANIZATION READ/NNP)
#   (ORGANIZATION MORE/NNP Fred/NNP Hassan/NNP)
#   Special/NNP
#   Limited/NNP
#   (PERSON Partner/NNP)
#   ,/,
#   (PERSON Warburg/NNP Pincus/NNP)
#   and/CC
#   (PERSON Chairman/NNP)
#   ,/,
#   (PERSON Caret/NNP Group/NNP Jessica/NNP Mega/NNP)
#   is/VBZ
#   the/DT
#   chief/JJ
#   medical/JJ
#   officer/NN
#   of/IN
#   (GPE Verily/NNP)
#   ./.)
# (S
#   She/PRP
#   is/VBZ
#   also/RB
#   a/DT
#   cardiologist/NN
#   who/WP
#   trained/VBD
#   and/CC
#   practiced/VBD
#   at/IN
#   (ORGANIZATION Massachusetts/NNP)
#   General/NNP
#   (ORGANIZATION Hospital/NNP)
#   and/CC
#   (GPE Brigham/NNP)
#   and/CC
#   (PERSON Women/NNP)
#   ’/NNP
#   s/JJ
#   (ORGANIZATION Hospital/NNP)
#   ./.)
# (S
#   (ORGANIZATION READ/NNP)
#   (ORGANIZATION MORE/NNP Jessica/NNP Mega/NNP)
#   ,/,
#   M.D./NNP
#   ,/,
#   M.P.H/NNP
#   Chief/NNP
#   (PERSON Medical/NNP Officer/NNP)
#   ,/,
#   (PERSON Verily/NNP)
#   Dr./NNP
#   (PERSON John/NNP H./NNP Noseworthy/NNP)
#   is/VBZ
#   president/NN
#   and/CC
#   chief/JJ
#   executive/JJ
#   officer/NN
#   of/IN
#   (ORGANIZATION Mayo/NNP Clinic/NNP)
#   ./.)
# (S
#   (ORGANIZATION READ/NNP)
#   (ORGANIZATION MORE/NNP)
#   (PERSON John/NNP Noseworthy/NNP)
#   ,/,
#   M.D/NNP
#   ./.)
# (S
#   President/NNP
#   and/CC
#   (ORGANIZATION CEO/NNP)
#   ,/,
#   (PERSON Mayo/NNP Clinic/NNP Sean/NNP Parker/NNP)
#   is/VBZ
#   the/DT
#   founder/NN
#   and/CC
#   president/NN
#   of/IN
#   The/DT
#   (ORGANIZATION Parker/NNP Foundation/NNP)
#   ./.)
# (S
#   He/PRP
#   helped/VBD
#   to/TO
#   establish/VB
#   the/DT
#   (FACILITY Stand/NNP)
#   Up/NNP
#   2/CD
#   Cancer/NNP
#   and/CC
#   (PERSON Cancer/NNP Research/NNP Institute/NNP)
#   's/POS
#   (/(
#   (ORGANIZATION CRI/NNP)
#   )/)
#   (PERSON Immunology/NNP Dream/NNP Team/NNP)
#   in/IN
#   2012/CD
#   ./.)
# (S
#   (ORGANIZATION READ/NNP)
#   (ORGANIZATION MORE/NNP Sean/NNP Parker/NNP Founder/NNP)
#   and/CC
#   President/NNP
#   ,/,
#   The/DT
#   (ORGANIZATION Parker/NNP Foundation/NNP Eric/NNP Topol/NNP)
#   is/VBZ
#   the/DT
#   founder/NN
#   and/CC
#   director/NN
#   of/IN
#   the/DT
#   (ORGANIZATION
#     Scripps/NNP
#     Translational/NNP
#     Science/NNP
#     Institute/NNP)
#   and/CC
#   professor/NN
#   of/IN
#   (ORGANIZATION Molecular/JJ Medicine/NNP)
#   at/IN
#   the/DT
#   (ORGANIZATION Scripps/NNP Research/NNP Institute/NNP)
#   ./.)
# (S
#   (ORGANIZATION READ/NNP)
#   (ORGANIZATION MORE/NNP Eric/NNP Topol/NNP)
#   ,/,
#   M.D/NNP
#   ./.)
# (S
#   (GPE Founder/NNP)
#   and/CC
#   (PERSON Director/NNP)
#   ,/,
#   (PERSON
#     Scripps/NNP
#     Translational/NNP
#     Science/NNP
#     Institute/NNP
#     Anne/NNP
#     Wojcicki/NNP)
#   co-founded/VBD
#   23andMe/CD
#   in/IN
#   2006/CD
#   after/IN
#   a/DT
#   decade/NN
#   in/IN
#   health/NN
#   care/NN
#   investing/VBG
#   focusing/VBG
#   on/IN
#   biotechnology/NN
#   companies/NNS
#   ./.)
# (S
#   (ORGANIZATION READ/NNP)
#   (ORGANIZATION MORE/NNP Anne/NNP Wojcicki/NNP)
#   Co-Founder/NNP
#   and/CC
#   (ORGANIZATION CEO/NNP)
#   ,/,
#   23andMe/CD
#   Venue/NNP
#   The/DT
#   (ORGANIZATION Roosevelt/NNP)
#   Hotel/NNP
#   The/DT
#   (ORGANIZATION Roosevelt/NNP)
#   Hotel/NNP
#   45/CD
#   E/NNP
#   45th/CD
#   Street/NNP
#   (GPE New/NNP York/NNP)
#   ,/,
#   NY/NNP
#   10017/CD
#   There/EX
#   is/VBZ
#   a/DT
#   special/JJ
#   (ORGANIZATION CNBC/NNP)
#   room/NN
#   rate/NN
#   of/IN
#   $/$
#   219/CD
#   per/IN
#   night/NN
#   ,/,
#   plus/CC
#   tax/NN
#   ./.)
# (S
#   To/TO
#   reserve/VB
#   a/DT
#   room/NN
#   with/IN
#   this/DT
#   rate/NN
#   ,/,
#   please/VB
#   call/VB
#   the/DT
#   (ORGANIZATION Roosevelt/NNP Hotel/NNP)
#   directly/RB
#   at/IN
#   212-661-9600/JJ
#   ./.)
# (S
#   (GPE Please/NNP)
#   note/NN
#   this/DT
#   special/JJ
#   rate/NN
#   will/MD
#   be/VB
#   honored/VBN
#   until/IN
#   February/NNP
#   27/CD
#   ,/,
#   2018/CD
#   or/CC
#   until/IN
#   the/DT
#   limited/JJ
#   block/NN
#   has/VBZ
#   been/VBN
#   filled/VBN
#   ./.)
# (S (PERSON Click/NNP) here/RB for/IN hotel/NN directions/NNS ./.)
# (S
#   Sponsors/NNS
#   (ORGANIZATION CONTACT/NNP)
#   Are/NNP
#   you/PRP
#   looking/VBG
#   for/IN
#   more/JJR
#   information/NN
#   ?/.)
# (S
#   (GPE Please/NNP)
#   contact/VB
#   the/DT
#   following/NN
#   :/:
#   •/NN
#   For/IN
#   sponsorship/NN
#   opportunities/NNS
#   ,/,
#   contact/NN
#   (PERSON Alisha/NNP Hathaway/NNP)
#   •/NNP
#   For/IN
#   speaker/NN
#   and/CC
#   editorial/JJ
#   inquiries/NNS
#   ,/,
#   contact/JJ
#   Maneet/NNP
#   Ahuja/NNP
#   •/NNP
#   For/IN
#   press/NN
#   and/CC
#   media/NNS
#   inquiries/NNS
#   ,/,
#   contact/NN
#   (PERSON Jennifer/NNP Dauble/NNP)
#   •/NN
#   For/IN
#   other/JJ
#   questions/NNS
#   ,/,
#   contact/NN
#   healthyreturns/NNS
#   @/VBP
#   cnbc.com/NN)
# (S
#   Stocks/NNS
#   rose/VBD
#   to/TO
#   record/VB
#   highs/NNS
#   on/IN
#   Friday/NNP
#   after/IN
#   some/DT
#   of/IN
#   the/DT
#   major/JJ
#   financial/JJ
#   companies/NNS
#   in/IN
#   the/DT
#   (GPE U.S./NNP)
#   reported/VBD
#   strong/JJ
#   quarterly/JJ
#   results/NNS
#   ./.)
# (S
#   The/DT
#   (ORGANIZATION Dow/NNP Jones/NNP)
#   industrial/JJ
#   average/NN
#   rose/VBD
#   228.46/CD
#   points/NNS
#   to/TO
#   close/VB
#   at/IN
#   25,803.19/CD
#   ,/,
#   an/DT
#   all-time/JJ
#   high/NN
#   ./.)
# (S
#   J.P./NNP
#   Morgan/NNP
#   Chase/NNP
#   was/VBD
#   among/IN
#   the/DT
#   best-performing/JJ
#   stocks/NNS
#   in/IN
#   the/DT
#   index/NN
#   ,/,
#   rising/VBG
#   1.7/CD
#   percent/NN
#   ./.)
# (S
#   The/DT
#   S/NNP
#   &/CC
#   P/NNP
#   500/CD
#   also/RB
#   reached/VBD
#   a/DT
#   record/NN
#   high/NN
#   ,/,
#   climbing/VBG
#   0.7/CD
#   percent/NN
#   to/TO
#   2,786.24/CD
#   with/IN
#   energy/NN
#   and/CC
#   consumer/NN
#   discretionary/NN
#   as/IN
#   the/DT
#   best-performing/JJ
#   sectors/NNS
#   ./.)
# (S
#   (GPE Energy/NNP)
#   stocks/NNS
#   got/VBD
#   a/DT
#   boost/NN
#   from/IN
#   rising/VBG
#   oil/NN
#   prices/NNS
#   ./.)
# (S
#   The/DT
#   index/NN
#   is/VBZ
#   also/RB
#   enjoying/VBG
#   its/PRP$
#   best/JJS
#   10-day/JJ
#   start/NN
#   to/TO
#   a/DT
#   year/NN
#   since/IN
#   2003/CD
#   ./.)
# (S
#   In/IN
#   that/DT
#   time/NN
#   period/NN
#   ,/,
#   the/DT
#   S/NNP
#   &/CC
#   P/NNP
#   500/CD
#   is/VBZ
#   up/RB
#   4.2/CD
#   percent/NN
#   ./.)
# (S
#   It/PRP
#   gained/VBD
#   5.9/CD
#   percent/NN
#   during/IN
#   the/DT
#   first/JJ
#   10/CD
#   days/NNS
#   of/IN
#   2003/CD
#   ./.)
# (S
#   ``/``
#   There/EX
#   is/VBZ
#   optimism/NN
#   in/IN
#   the/DT
#   market/NN
#   ,/,
#   ''/''
#   but/CC
#   there/EX
#   is/VBZ
#   also/RB
#   uncertainty/NN
#   about/IN
#   this/DT
#   rally/NN
#   ,/,
#   said/VBD
#   (PERSON Cooper/NNP Abbott/NNP)
#   ,/,
#   chairman/NN
#   of/IN
#   (PERSON Carillon/NNP Tower/NNP Advisers/NNP)
#   ./.)
# (S
#   That/DT
#   level/NN
#   of/IN
#   uncertainty/NN
#   can/MD
#   be/VB
#   good/JJ
#   for/IN
#   the/DT
#   market/NN
#   because/IN
#   it/PRP
#   ``/``
#   dampens/JJ
#   expectations/NNS
#   ./.
#   ''/'')
# (S
#   The/DT
#   (ORGANIZATION Nasdaq/NNP)
#   composite/JJ
#   finished/VBD
#   0.7/CD
#   percent/NN
#   higher/JJR
#   at/IN
#   7,261.06/CD
#   ./.)
# (S
#   (GPE Amazon/NNP)
#   shares/NNS
#   rose/VBD
#   2.2/CD
#   percent/NN
#   and/CC
#   broke/VBD
#   above/IN
#   $/$
#   1,300/CD
#   for/IN
#   the/DT
#   first/JJ
#   time/NN
#   ./.)
# (S
#   J.P./NNP
#   Morgan/NNP
#   Chase/NNP
#   ,/,
#   (ORGANIZATION BlackRock/NNP)
#   and/CC
#   (PERSON Wells/NNP Fargo/NNP)
#   all/DT
#   reported/VBD
#   better-than-expected/JJ
#   quarterly/JJ
#   results/NNS
#   ./.)
# (S
#   (PERSON Brendan/NNP)
#   (ORGANIZATION McDermid/NNP)
#   |/NNP
#   Reuters/NNP
#   Traders/NNP
#   work/NN
#   on/IN
#   the/DT
#   floor/NN
#   of/IN
#   the/DT
#   (GPE New/NNP York/NNP)
#   Stock/NNP
#   Exchange/NNP
#   ./.)
# (S
#   S/NNP
#   &/CC
#   P/NNP
#   500/CD
#   profits/NNS
#   are/VBP
#   expected/VBN
#   to/TO
#   have/VB
#   risen/VBN
#   11.2/CD
#   percent/NN
#   in/IN
#   the/DT
#   fourth/JJ
#   quarter/NN
#   of/IN
#   last/JJ
#   year/NN
#   ./.)
# (S
#   All/DT
#   11/CD
#   S/NNP
#   &/CC
#   P/NNP
#   500/CD
#   sectors/NNS
#   ,/,
#   meanwhile/RB
#   ,/,
#   are/VBP
#   expected/VBN
#   to/TO
#   post/VB
#   increases/NNS
#   in/IN
#   both/DT
#   earnings/NNS
#   and/CC
#   revenue/NN
#   ,/,
#   according/VBG
#   to/TO
#   (ORGANIZATION FactSet/NNP)
#   ./.)
# (S
#   This/DT
#   would/MD
#   be/VB
#   the/DT
#   first/JJ
#   time/NN
#   since/IN
#   2011/CD
#   that/IN
#   all/PDT
#   the/DT
#   sectors/NNS
#   in/IN
#   the/DT
#   S/NNP
#   &/CC
#   P/NNP
#   500/CD
#   posted/VBD
#   sales/NNS
#   and/CC
#   profit/NN
#   growth/NN
#   for/IN
#   the/DT
#   same/JJ
#   quarter/NN
#   ./.)
# (S
#   Stocks/NNS
#   have/VBP
#   carried/VBN
#   over/IN
#   the/DT
#   momentum/NN
#   from/IN
#   2017/CD
#   into/IN
#   the/DT
#   new/JJ
#   year/NN
#   thus/RB
#   far/RB
#   ./.)
# (S
#   The/DT
#   S/NNP
#   &/CC
#   P/NNP
#   500/CD
#   and/CC
#   (GPE Nasdaq/NNP)
#   have/VBP
#   closed/VBN
#   lower/JJR
#   only/RB
#   once/RB
#   this/DT
#   year/NN
#   ,/,
#   while/IN
#   the/DT
#   (ORGANIZATION Dow/NNP)
#   has/VBZ
#   fallen/VBN
#   just/RB
#   twice/RB
#   ./.)
# (S
#   For/IN
#   2018/CD
#   ,/,
#   the/DT
#   major/JJ
#   averages/NNS
#   are/VBP
#   up/RB
#   at/IN
#   least/JJS
#   3.5/CD
#   percent/NN
#   entering/VBG
#   Friday/NNP
#   's/POS
#   session/NN
#   ./.)
# (S
#   For/IN
#   the/DT
#   week/NN
#   ,/,
#   they/PRP
#   posted/VBD
#   gains/NNS
#   of/IN
#   at/IN
#   least/JJS
#   1.6/CD
#   percent/NN
#   ./.)
# (S
#   The/DT
#   (ORGANIZATION Dow/NNP)
#   outperformed/VBD
#   the/DT
#   (ORGANIZATION Nasdaq/NNP)
#   and/CC
#   S/NNP
#   &/CC
#   P/NNP
#   500/CD
#   this/DT
#   week/NN
#   ,/,
#   gaining/VBG
#   2/CD
#   percent/NN
#   ,/,
#   as/IN
#   (ORGANIZATION Boeing/NNP)
#   shares/NNS
#   have/VBP
#   soared/VBN
#   8.9/CD
#   percent/NN
#   ./.)
# (S
#   ``/``
#   The/DT
#   most/RBS
#   important/JJ
#   dynamic/JJ
#   to/TO
#   focus/VB
#   on/IN
#   in/IN
#   the/DT
#   market/NN
#   is/VBZ
#   growth/NN
#   ,/,
#   ''/''
#   said/VBD
#   (PERSON Sandip/NNP Bhagat/NNP)
#   ,/,
#   chief/JJ
#   investment/NN
#   officer/NN
#   at/IN
#   (FACILITY Whittier/NNP Trust/NNP)
#   ./.)
# (S
#   He/PRP
#   acknowledged/VBD
#   that/IN
#   risks/NNS
#   to/TO
#   the/DT
#   rally/NN
#   do/VBP
#   exist/VB
#   ,/,
#   but/CC
#   added/VBD
#   :/:
#   ``/``
#   They/PRP
#   pale/VBP
#   in/IN
#   comparison/NN
#   to/TO
#   the/DT
#   economic/JJ
#   growth/NN
#   we/PRP
#   're/VBP
#   seeing/VBG
#   ./.
#   ''/'')
# (S
#   Recent/JJ
#   data/NNS
#   suggests/VBZ
#   the/DT
#   (GPE U.S./NNP)
#   economy/NN
#   is/VBZ
#   picking/VBG
#   up/RP
#   steam/NN
#   ./.)
# (S
#   The/DT
#   (ORGANIZATION Labor/NNP Department/NNP)
#   said/VBD
#   its/PRP$
#   Consumer/NNP
#   Price/NNP
#   Index/NNP
#   excluding/VBG
#   the/DT
#   volatile/JJ
#   food/NN
#   and/CC
#   energy/NN
#   components/NNS
#   rose/VBD
#   0.3/CD
#   percent/NN
#   last/JJ
#   month/NN
#   ./.)
# (S
#   That/DT
#   was/VBD
#   the/DT
#   biggest/JJS
#   advance/NN
#   in/IN
#   the/DT
#   so-called/JJ
#   core/NN
#   (ORGANIZATION CPI/NNP)
#   since/IN
#   January/NNP
#   ./.)
# (S
#   (GPE Treasury/NNP)
#   yields/NNS
#   ticked/VBD
#   higher/RBR
#   following/VBG
#   the/DT
#   data/NN
#   release/NN
#   ./.)
# (S
#   The/DT
#   two-year/JJ
#   yield/NN
#   broke/VBD
#   above/IN
#   2/CD
#   percent/NN
#   for/IN
#   the/DT
#   first/JJ
#   time/NN
#   since/IN
#   September/NNP
#   2008/CD
#   ./.)
# (S It/PRP traded/VBD at/IN 2.01/CD percent/NN ./.)
# (S —Reuters/NNS contributed/VBD to/TO this/DT report/NN ./.)
# (S
#   (GPE Getty/NNP)
#   Images/VBZ
#   A/NNP
#   trader/NN
#   wears/VBZ
#   a/DT
#   DOW/NNP
#   24,000/CD
#   hat/NN
#   as/IN
#   he/PRP
#   works/VBZ
#   on/IN
#   the/DT
#   floor/NN
#   of/IN
#   the/DT
#   (GPE New/NNP York/NNP)
#   Stock/NNP
#   Exchange/NNP
#   ,/,
#   (/(
#   (ORGANIZATION NYSE/NNP)
#   )/)
#   as/IN
#   the/DT
#   (ORGANIZATION Dow/NNP Jones/NNP Industrial/NNP Average/NNP)
#   crosses/VBZ
#   25,000/CD
#   on/IN
#   Jan./NNP
#   4ht/CD
#   ,/,
#   2018/CD
#   for/IN
#   the/DT
#   first/JJ
#   time/NN
#   ./.)
# (S
#   (GPE U.S./NNP)
#   stock/NN
#   index/NN
#   futures/NNS
#   gave/VBD
#   back/RP
#   some/DT
#   of/IN
#   their/PRP$
#   gains/NNS
#   on/IN
#   Friday/NNP
#   after/IN
#   the/DT
#   release/NN
#   of/IN
#   key/JJ
#   inflation/NN
#   data/NNS
#   ./.)
# (S
#   (PERSON Dow/NNP)
#   (PERSON Jones/NNP)
#   industrial/JJ
#   average/NN
#   futures/NNS
#   traded/VBD
#   72/CD
#   points/NNS
#   higher/RBR
#   ;/:
#   they/PRP
#   had/VBD
#   risen/VBN
#   more/JJR
#   than/IN
#   100/CD
#   points/NNS
#   earlier/RBR
#   in/IN
#   the/DT
#   session/NN
#   ./.)
# (S
#   S/NNP
#   &/CC
#   P/NNP
#   500/CD
#   futurews/NNS
#   were/VBD
#   down/RB
#   half/PDT
#   a/DT
#   point/NN
#   and/CC
#   (ORGANIZATION Nasdaq/NNP)
#   100/CD
#   futures/NNS
#   fell/VBD
#   21/CD
#   points/NNS
#   ./.)
# (S
#   The/DT
#   (ORGANIZATION Labor/NNP Department/NNP)
#   said/VBD
#   its/PRP$
#   Consumer/NNP
#   Price/NNP
#   Index/NNP
#   excluding/VBG
#   the/DT
#   volatile/JJ
#   food/NN
#   and/CC
#   energy/NN
#   components/NNS
#   rose/VBD
#   0.3/CD
#   percent/NN
#   last/JJ
#   month/NN
#   ./.)
# (S
#   That/DT
#   was/VBD
#   the/DT
#   biggest/JJS
#   advance/NN
#   in/IN
#   the/DT
#   so-called/JJ
#   core/NN
#   (ORGANIZATION CPI/NNP)
#   since/IN
#   January/NNP
#   ./.)
# (S
#   (GPE Equity/NN)
#   futures/NNS
#   had/VBD
#   risen/VBN
#   after/IN
#   (PERSON Wells/NNP Fargo/NNP)
#   and/CC
#   (ORGANIZATION J.P./NNP Morgan/NNP)
#   Chase/NNP
#   reported/VBD
#   better-than-expected/JJ
#   quarterly/JJ
#   results/NNS
#   ./.)
# (S
#   (ORGANIZATION BlackRock/NNP)
#   also/RB
#   posted/VBD
#   results/NNS
#   that/IN
#   beat/JJ
#   expectations/NNS
#   ./.)
# (S
#   On/IN
#   Thursday/NNP
#   ,/,
#   the/DT
#   (ORGANIZATION Dow/NNP)
#   hit/VBD
#   an/DT
#   all-time/JJ
#   high/NN
#   ,/,
#   with/IN
#   the/DT
#   index/NN
#   rising/VBG
#   more/JJR
#   than/IN
#   200/CD
#   points/NNS
#   by/IN
#   the/DT
#   close/NN
#   ./.)
# (S
#   The/DT
#   state/NN
#   of/IN
#   the/DT
#   (GPE U.S./NNP)
#   economy/NN
#   and/CC
#   tax/NN
#   reform/NN
#   is/VBZ
#   set/VBN
#   to/TO
#   be/VB
#   of/IN
#   key/JJ
#   importance/NN
#   on/IN
#   Friday/NNP
#   as/IN
#   major/JJ
#   (GPE U.S./NNP)
#   banks/NNS
#   are/VBP
#   set/VBN
#   to/TO
#   report/VB
#   ./.)
# (S
#   Markets/NNS
#   have/VBP
#   been/VBN
#   on/IN
#   the/DT
#   rise/NN
#   as/IN
#   of/IN
#   late/JJ
#   ,/,
#   after/IN
#   President/NNP
#   (PERSON Donald/NNP Trump/NNP)
#   signed/VBD
#   a/DT
#   bill/NN
#   in/IN
#   December/NNP
#   to/TO
#   slash/VB
#   the/DT
#   corporate/JJ
#   tax/NN
#   rate/NN
#   from/IN
#   35/CD
#   percent/NN
#   to/TO
#   21/CD
#   percent/NN
#   ./.)
# (S
#   Meantime/RB
#   ,/,
#   investors/NNS
#   will/MD
#   keep/VB
#   a/DT
#   close/JJ
#   eye/NN
#   on/IN
#   bond/NN
#   markets/NNS
#   ,/,
#   after/IN
#   investors/NNS
#   fretted/VBD
#   over/IN
#   the/DT
#   risk/NN
#   of/IN
#   (GPE China/NNP)
#   halting/VBG
#   its/PRP$
#   (ORGANIZATION Treasury/NNP)
#   bond/NN
#   purchases/NNS
#   ./.)
# (S
#   (PERSON Vote/NNP)
#   (ORGANIZATION Vote/NNP)
#   to/TO
#   see/VB
#   results/NNS
#   (ORGANIZATION Total/JJ)
#   Votes/NNS
#   :/:
#   Not/RB
#   a/DT
#   (ORGANIZATION Scientific/NNP Survey/NNP)
#   ./.)
# (S
#   Results/NNS
#   may/MD
#   not/RB
#   total/VB
#   100/CD
#   %/NN
#   due/JJ
#   to/TO
#   rounding/VBG
#   ./.)
# (S
#   On/IN
#   Wednesday/NNP
#   ,/,
#   (ORGANIZATION Bloomberg/NNP News/NNP)
#   reported/VBD
#   ,/,
#   citing/VBG
#   people/NNS
#   familiar/JJ
#   with/IN
#   the/DT
#   matter/NN
#   ,/,
#   that/WDT
#   officials/NNS
#   in/IN
#   (GPE Beijing/NNP)
#   had/VBD
#   recommended/VBN
#   that/IN
#   (GPE China/NNP)
#   's/POS
#   government/NN
#   lowers/NNS
#   —/VBP
#   or/CC
#   even/RB
#   potentially/RB
#   ceases/VBZ
#   —/VB
#   its/PRP$
#   buying/NN
#   of/IN
#   (GPE U.S./NNP)
#   sovereign/JJ
#   debt/NN
#   ./.)
# (S
#   However/RB
#   ,/,
#   (GPE China/NNP)
#   's/POS
#   currency/NN
#   regulator/NN
#   has/VBZ
#   since/IN
#   refuted/VBN
#   the/DT
#   report/NN
#   ./.)
# (S
#   On/IN
#   the/DT
#   (GPE U.S./NNP)
#   central/JJ
#   bank/NN
#   front/NN
#   ,/,
#   (PERSON Boston/NNP Fed/NNP)
#   President/NNP
#   (PERSON Eric/NNP Rosengren/NNP)
#   is/VBZ
#   expected/VBN
#   to/TO
#   be/VB
#   in/IN
#   (GPE California/NNP)
#   ,/,
#   where/WRB
#   he/PRP
#   's/VBZ
#   set/VBN
#   to/TO
#   give/VB
#   a/DT
#   keynote/NN
#   address/NN
#   at/IN
#   the/DT
#   (ORGANIZATION Money/NNP)
#   ,/,
#   (GPE Models/NNP)
#   ,/,
#   and/CC
#   (ORGANIZATION Digital/NNP Innovation/NNP)
#   conference/NN
#   in/IN
#   (GPE San/NNP Diego/NNP)
#   ./.)
# (S
#   Meantime/RB
#   ,/,
#   (GSP Philadelphia/NNP)
#   Fed/NNP
#   President/NNP
#   (PERSON Patrick/NNP Harker/NNP)
#   is/VBZ
#   expected/VBN
#   to/TO
#   be/VB
#   present/JJ
#   at/IN
#   the/DT
#   (ORGANIZATION Central/NNP Bucks/NNP)
#   Chamber/NNP
#   of/IN
#   (ORGANIZATION Commerce/NNP Economic/NNP Luncheon/NNP)
#   in/IN
#   (GPE Pennsylvania/NNP)
#   ./.)
# (S
#   Overseas/RB
#   ,/,
#   coalition/NN
#   party/NN
#   leaders/NNS
#   in/IN
#   (GPE Germany/NNP)
#   have/VBP
#   reached/VBN
#   a/DT
#   breakthrough/NN
#   in/IN
#   talks/NNS
#   to/TO
#   form/VB
#   a/DT
#   new/JJ
#   government/NN
#   ./.)
# (S
#   (GPE German/JJ)
#   (ORGANIZATION Chancellor/NNP Angela/NNP Merkel/NNP)
#   had/VBD
#   entered/VBN
#   into/IN
#   talks/NNS
#   with/IN
#   a/DT
#   rival/JJ
#   party/NN
#   in/IN
#   a/DT
#   last-ditch/JJ
#   effort/NN
#   to/TO
#   form/VB
#   a/DT
#   coalition/NN
#   government/NN
#   ./.)
# (S
#   This/DT
#   comes/VBZ
#   after/IN
#   months/NNS
#   of/IN
#   political/JJ
#   uncertainty/NN
#   ./.)
# (S —Reuters/NNS contributed/VBD to/TO this/DT report/NN ./.)
# (S
#   (PERSON Oleg/NNP)
#   (PERSON Popov/NNP)
#   |/NNP
#   Reuters/NNP
#   The/DT
#   stock/NN
#   market/NN
#   will/MD
#   enjoy/VB
#   a/DT
#   ``/``
#   Made/NNP
#   in/IN
#   (GPE America/NNP)
#   ''/''
#   boom/NN
#   this/DT
#   year/NN
#   thanks/VBZ
#   to/TO
#   a/DT
#   slew/NN
#   of/IN
#   policies/NNS
#   spearheaded/VBN
#   by/IN
#   the/DT
#   (ORGANIZATION Trump/NNP)
#   administration/NN
#   ,/,
#   according/VBG
#   to/TO
#   a/DT
#   (FACILITY Wall/NNP Street/NNP)
#   investment/NN
#   bank/NN
#   ./.)
# (S
#   Some/DT
#   of/IN
#   the/DT
#   nation/NN
#   's/POS
#   largest/JJS
#   industrial/JJ
#   and/CC
#   steel/NN
#   companies/NNS
#   will/MD
#   rally/VB
#   under/IN
#   President/NNP
#   (PERSON Donald/NNP Trump/NNP)
#   's/POS
#   focus/NN
#   on/IN
#   domestic/JJ
#   prosperity/NN
#   ,/,
#   spelling/VBG
#   even/RB
#   more/RBR
#   upside/JJ
#   for/IN
#   investors/NNS
#   ,/,
#   according/VBG
#   to/TO
#   Jefferies/NNPS
#   ./.)
# (S
#   With/IN
#   the/DT
#   (GPE U.S./NNP)
#   thinking/NN
#   about/IN
#   leaving/VBG
#   (ORGANIZATION NAFTA/NNP)
#   ,/,
#   ``/``
#   new/JJ
#   tax/NN
#   incentives/NNS
#   to/TO
#   repatriate/VB
#   profits/NNS
#   in/IN
#   place/NN
#   and/CC
#   the/DT
#   dollar/NN
#   weak/JJ
#   ,/,
#   the/DT
#   ingredients/NNS
#   for/IN
#   a/DT
#   domestic/JJ
#   investment/NN
#   boom/NN
#   are/VBP
#   in/IN
#   place/NN
#   ,/,
#   ''/''
#   analyst/NN
#   (PERSON Sean/NNP Darby/NNP)
#   wrote/VBD
#   Thursday/NNP
#   ./.)
# (S
#   ``/``
#   While/IN
#   the/DT
#   corporate/JJ
#   sector/NN
#   is/VBZ
#   obviously/RB
#   euphoric/JJ
#   over/IN
#   the/DT
#   tax/NN
#   changes/NNS
#   ,/,
#   it/PRP
#   is/VBZ
#   not/RB
#   often/RB
#   highlighted/VBN
#   that/IN
#   it/PRP
#   has/VBZ
#   improved/VBN
#   (GPE U.S./NNP)
#   's/POS
#   competitive/JJ
#   position/NN
#   ./.
#   ''/'')
# (S
#   show/NN
#   chapters/NNS
#   These/DT
#   NAFTA-sensitive/JJ
#   stocks/NNS
#   are/VBP
#   moving/VBG
#   on/IN
#   trade/NN
#   talks/NNS
#   7:58/CD
#   AM/NNP
#   ET/NNP
#   Thu/NNP
#   ,/,
#   11/CD
#   Jan/NNP
#   2018/CD
#   |/NNP
#   02:16/CD
#   Trump/NNP
#   and/CC
#   (ORGANIZATION Republican/NNP)
#   lawmakers/NNS
#   clinched/VBD
#   a/DT
#   major/JJ
#   legislative/JJ
#   victory/NN
#   by/IN
#   passing/VBG
#   the/DT
#   (ORGANIZATION Tax/NNP Cuts/NNP)
#   and/CC
#   (PERSON Jobs/NNP Act/NNP)
#   in/IN
#   late/JJ
#   2017/CD
#   ,/,
#   reducing/VBG
#   the/DT
#   corporate/JJ
#   tax/NN
#   rate/NN
#   to/TO
#   21/CD
#   percent/NN
#   and/CC
#   offering/VBG
#   new/JJ
#   incentives/NNS
#   for/IN
#   companies/NNS
#   to/TO
#   repatriate/VB
#   profits/NNS
#   ./.)
# (S
#   The/DT
#   (ORGANIZATION GOP/NNP)
#   hopes/VBZ
#   that/IN
#   by/IN
#   amending/VBG
#   the/DT
#   tax/NN
#   code/VBZ
#   the/DT
#   economy/NN
#   will/MD
#   surge/VB
#   further/RBR
#   ,/,
#   and/CC
#   drive/VBP
#   most/RBS
#   investing/JJ
#   dollars/NNS
#   into/IN
#   the/DT
#   U.S/NNP
#   ./.)
# (S
#   But/CC
#   even/RB
#   as/IN
#   some/DT
#   of/IN
#   the/DT
#   country/NN
#   's/POS
#   industrial/JJ
#   titans/NNS
#   catch/VBP
#   a/DT
#   tax/NN
#   break/NN
#   ,/,
#   the/DT
#   fate/NN
#   of/IN
#   some/DT
#   of/IN
#   the/DT
#   country/NN
#   's/POS
#   most/RBS
#   iconic/JJ
#   trade/NN
#   agreements/NNS
#   hang/VBP
#   in/IN
#   the/DT
#   balance/NN
#   ./.)
# (S
#   (GPE Trump/NNP)
#   is/VBZ
#   currently/RB
#   debating/VBG
#   (GPE U.S./NNP)
#   participation/NN
#   in/IN
#   (GPE NAFTA/NNP)
#   ,/,
#   the/DT
#   iconic/JJ
#   24-year-old/JJ
#   trade/NN
#   pact/NN
#   with/IN
#   (GPE Canada/NNP)
#   and/CC
#   (GPE Mexico/NNP)
#   ./.)
# (S
#   Should/MD
#   the/DT
#   (GPE U.S./NNP)
#   pull/VBZ
#   out/IN
#   of/IN
#   the/DT
#   agreement/NN
#   ,/,
#   incentives/VBZ
#   to/TO
#   ``/``
#   off-shore/JJ
#   ''/''
#   factories/NNS
#   could/MD
#   diminish/VB
#   ./.)
# (S
#   ``/``
#   The/DT
#   (ORGANIZATION NAFTA/NNP)
#   trade/NN
#   agreement/NN
#   encouraged/VBD
#   'off-shoring/VBG
#   '/''
#   or/CC
#   the/DT
#   placement/NN
#   of/IN
#   (GPE U.S./NNP)
#   manufacturing/NN
#   in/IN
#   its/PRP$
#   neighbors/NNS
#   due/JJ
#   to/TO
#   better/RBR
#   labor/NN
#   laws/NNS
#   ,/,
#   cheaper/JJR
#   exchange/NN
#   rates/NNS
#   and/or/VBP
#   lower/JJR
#   wages/NNS
#   ,/,
#   ''/''
#   added/VBD
#   (PERSON Darby/NNP)
#   ./.)
# (S
#   ``/``
#   Coincidentally/RB
#   ,/,
#   next/JJ
#   Tuesday/NNP
#   ,/,
#   the/DT
#   (ORGANIZATION U.S./NNP Department/NNP)
#   of/IN
#   (ORGANIZATION Commerce/NNP)
#   is/VBZ
#   expected/VBN
#   to/TO
#   provide/VB
#   formal/JJ
#   recommendations/NNS
#   to/TO
#   the/DT
#   President/NNP
#   regarding/VBG
#   possible/JJ
#   action/NN
#   to/TO
#   combat/VB
#   (GPE U.S./NNP)
#   steel/NN
#   imports/NNS
#   on/IN
#   national/JJ
#   security/NN
#   grounds/NNS
#   ./.
#   ''/'')
# (S
#   Such/JJ
#   decisions/NNS
#   by/IN
#   the/DT
#   (ORGANIZATION Trump/NNP)
#   administration/NN
#   are/VBP
#   likely/JJ
#   already/RB
#   having/VBG
#   an/DT
#   effect/NN
#   on/IN
#   the/DT
#   business/NN
#   world/NN
#   ./.)
# (S
#   The/DT
#   (ORGANIZATION Dow/NNP Jones/NNP)
#   industrial/JJ
#   average/NN
#   added/VBD
#   more/JJR
#   than/IN
#   150/CD
#   points/NNS
#   to/TO
#   claim/VB
#   another/DT
#   all-time/JJ
#   high/JJ
#   Thursday/NNP
#   while/IN
#   both/CC
#   the/DT
#   S/NNP
#   &/CC
#   P/NNP
#   500/CD
#   and/CC
#   the/DT
#   (ORGANIZATION Nasdaq/NNP)
#   hit/NN
#   records/NNS
#   ./.)
# (S
#   The/DT
#   gains/NNS
#   in/IN
#   the/DT
#   Dow/NNP
#   have/VBP
#   largely/RB
#   stemmed/VBN
#   from/IN
#   industrial/JJ
#   giants/NNS
#   Boeing/NNP
#   ,/,
#   (PERSON Chevron/NNP)
#   and/CC
#   (GPE Caterpillar/NNP)
#   ,/,
#   seen/VBN
#   as/IN
#   key/JJ
#   beneficiaries/NNS
#   from/IN
#   the/DT
#   tax/NN
#   changes/NNS
#   ./.)
# (S
#   The/DT
#   materials/NNS
#   sector/NN
#   ,/,
#   including/VBG
#   the/DT
#   nation/NN
#   's/POS
#   largest/JJS
#   steel/NN
#   manufacturers/NNS
#   ,/,
#   should/MD
#   also/RB
#   benefit/VB
#   from/IN
#   more/RBR
#   protective/JJ
#   policies/NNS
#   ,/,
#   said/VBD
#   (PERSON Darby/NNP)
#   ,/,
#   even/RB
#   as/IN
#   factory/NN
#   activity/NN
#   climbs/NN
#   ./.)
# (S
#   ``/``
#   The/DT
#   bottom/JJ
#   line/NN
#   is/VBZ
#   that/IN
#   the/DT
#   backdrop/NN
#   for/IN
#   the/DT
#   (GPE U.S./NNP)
#   materials/NNS
#   sector/NN
#   is/VBZ
#   improving/VBG
#   ,/,
#   ''/''
#   wrote/VBD
#   (PERSON Darby/NNP)
#   ./.)
# (S
#   ``/``
#   The/DT
#   cocktail/NN
#   of/IN
#   tax/NN
#   reform/NN
#   ,/,
#   (ORGANIZATION NAFTA/NNP)
#   ,/,
#   steel/NN
#   tariffs/NNS
#   ,/,
#   and/CC
#   booming/VBG
#   investment/NN
#   intentions/NNS
#   comes/VBZ
#   at/IN
#   a/DT
#   time/NN
#   when/WRB
#   the/DT
#   (ORGANIZATION ISM/NNP)
#   manufacturing/NN
#   index/NN
#   is/VBZ
#   surging/VBG
#   ./.
#   ''/'')
# (S
#   Names/NNS
#   like/IN
#   (GPE United/NNP States/NNPS Steel/NNP)
#   ,/,
#   (ORGANIZATION Commercial/JJ Metals/NNS)
#   and/CC
#   (PERSON Steel/NNP)
#   Dynamics/NNS
#   are/VBP
#   the/DT
#   ``/``
#   best/JJS
#   positioned/VBN
#   ''/''
#   to/TO
#   benefit/VB
#   from/IN
#   steel/NN
#   tariffs/NNS
#   ,/,
#   (PERSON Darby/NNP)
#   said/VBD
#   ,/,
#   all/DT
#   of/IN
#   which/WDT
#   have/VBP
#   buy/VBN
#   ratings/NNS
#   from/IN
#   the/DT
#   investment/NN
#   bank/NN
#   ./.)
# (S
#   The/DT
#   companies/NNS
#   were/VBD
#   up/RB
#   0.75/CD
#   percent/NN
#   ,/,
#   2.1/CD
#   percent/NN
#   ,/,
#   and/CC
#   1.7/CD
#   percent/NN
#   respectively/RB
#   during/IN
#   Thursday/NNP
#   trading/NN
#   ./.)
# (S
#   (PERSON Disclaimer/NNP)
#   WATCH/NNP
#   :/:
#   US/PRP
#   playing/VBG
#   'Russian/JJ
#   roulette/NN
#   '/''
#   with/IN
#   Canada-NAFTA/JJ
#   talks/NNS
#   show/VBP
#   chapters/NNS
#   (GSP US/NNP)
#   playing/VBG
#   'Russian/JJ
#   roulette/NN
#   '/''
#   in/IN
#   Canada-NAFTA/JJ
#   talks/NNS
#   :/:
#   Former/NNP
#   (ORGANIZATION US/NNP Ambassador/NNP)
#   to/TO
#   (GPE Canada/NNP)
#   7:22/CD
#   AM/NNP
#   ET/NNP
#   Thu/NNP
#   ,/,
#   11/CD
#   Jan/NNP
#   2018/CD
#   |/VBD
#   02:39/CD)
# ABOUT
# SPEAKERS
# AGENDA
# ADVISORY BOARD
# VENUE
# SPONSORS
# CONTACT
# About
# How innovators and investors are working with patients and providers to develop dynamic new solutions and create healthy returns.
# CNBC presents a one-day event at NYC’s Roosevelt Hotel that brings together top health care investors, CEOs and technologists to explore the innovations that will drive better outcomes, financially and clinically.
# Every health care company seeks to scale the best technology and develop profitable ways to cover the massive cost of research and development, investors are looking for actionable intelligence on who’s breaking through, and patients are hungry for affordable and effective care.
# Healthy Returns is a convening of leaders who are improving patient outcomes, maximizing innovation, building great new companies and reinventing incumbents.
# Led by CNBC’s anchors and reporters and with input from a world-class advisory board, Healthy Returns will hone in on groundbreaking ideas that will transform the health care industry, cutting through the noise and weeding out the "sales pitch."
# Attendees should expect to walk away with smart strategies and actionable insights from people who are shaping the industry, including:
# • Investment ideas and intelligence from the biggest and best health care hedge funds, venture capitalists and portfolio managers.
# • Strategic perspective from top health care CEOs.
# • An early, inside look at groundbreaking, transformative innovations.
# • Unique networking opportunities to connect with leaders in multiple disciplines – investors, executives, entrepreneurs and innovators.
# Who should attend:
# Health care investors, VCs, C-Suite executives from the biotech, pharma, health care and life sciences industries, health care IT BDMs.
# Speakers
# More speakers will be announced soon.
# Tap or click a card to reveal more information:
# Amy Abernethy M.D., PhD, serves as chief medical officer, chief scientific officer and senior vice president, oncology of Flatiron Health.
# READ MORE
# Amy Abernethy M.D., PhDChief Medical Officer, Chief Scientific Officer, Senior Vice President, Flatiron Health
# Bill George is an American businessman and academic.
# He is professor of Management Practice and a Henry B. Arthur Fellow of Ethics, at Harvard Business School.
# READ MORE
# Bill GeorgeSenior Fellow, Harvard Business School and Former Chairman and CEO, Medtronic
# Dr. Gottlieb is the 23rd commissioner of the Food and Drug Administration.
# READ MORE
# Scott Gottlieb, M.D.Commissioner of Food and Drugs, U.S. FDA
# Fred Hassan is a special limited partner and managing director with the private equity firm, Warburg Pincus and chairman of Caret Group.
# READ MORE
# Fred HassanSpecial Limited Partner, Warburg Pincus and Chairman, Caret Group
# Leonard S. Schleifer, M.D., PhD, is the founder, president and chief executive officer of Regeneron Pharmaceuticals.
# READ MORE
# Leonard S. Schleifer, M.D., PhD
# Founder, President and CEO, Regeneron Pharmaceuticals
# Agenda
# Agenda coming soon
# Advisory Board
# Tap or click a card to reveal more information:
# Amy Abernethy M.D., PhD, serves as chief medical officer, chief scientific officer and senior vice president, oncology of Flatiron Health.
# READ MORE
# Amy Abernethy M.D., PhD
# Chief Medical Officer, Chief Scientific Officer, Senior Vice President, Flatiron Health
# Dr. Coles is the chairman and chief executive officer of Yumanity Therapeutics, a biotechnology company.
# He also serves as chairman and chief executive officer of TRATE Enterprises LLC.
# READ MORE
# Tony Coles, M.D.
# Chairman and CEO, Yumanity Therapeutics
# Dr. Cosgrove is president and chief executive officer of Cleveland Clinic, presiding over an $8 billion health-care system.
# READ MORE
# Delos M. Cosgrove, M.D.
# President and CEO, Cleveland Clinic
# Dr. Kenneth L. Davis, is president and chief executive officer
# of the Mount Sinai Health System in New York City, one of the nation's largest integrated health systems.
# READ MORE
# Kenneth Davis, M.D.
# President and CEO, Mount Sinai Health System
# Dr. Sue Desmond-Hellmann is a physician, scientist and philanthropist and is currently the chief executive officer of the Bill & Melinda Gates Foundation.
# READ MORE
# Sue Desmond-Hellmann
# CEO, Bill & Melinda Gates Foundation
# Esther Dyson is chairman of EDventure Holdings.
# Her primary activity is investing in and nurturing start-ups, with a recent focus on health care, human capital and aerospace.
# READ MORE
# Esther Dyson
# Chairman, EDventure Holdings
# Bill George is an American businessman and academic.
# He is professor of Management Practice and a Henry B. Arthur Fellow of Ethics at Harvard Business School.
# READ MORE
# Bill GeorgeSenior Fellow, Harvard Business School and Former Chairman and CEO, Medtronic
# Dr. Laurie H. Glimcher, president and chief executive officer of Dana-Farber Cancer Institute, is also chief executive officer of Dana-Farber/Partners CancerCare.
# READ MORE
# Laurie Glimcher, M.D.
# President and CEO, Dana-Farber Cancer Institute
# Fred Hassan is a special limited partner and managing director with the private equity firm, Warburg Pincus and chairman of Caret Group.
# READ MORE
# Fred Hassan
# Special Limited Partner, Warburg Pincus and Chairman, Caret Group
# Jessica Mega is the chief medical officer of Verily.
# She is also a cardiologist who trained and practiced at Massachusetts General Hospital and Brigham and Women’s Hospital.
# READ MORE
# Jessica Mega, M.D., M.P.H
# Chief Medical Officer, Verily
# Dr. John H. Noseworthy is president and chief executive officer
# of Mayo Clinic.
# READ MORE
# John Noseworthy, M.D.
# President and CEO, Mayo Clinic
# Sean Parker is the founder and president of The Parker Foundation.
# He helped to establish the Stand Up 2 Cancer and Cancer Research Institute's (CRI) Immunology Dream Team in 2012.
# READ MORE
# Sean Parker
# Founder and President, The Parker Foundation
# Eric Topol is the founder and director of the Scripps Translational Science Institute and professor of Molecular Medicine at the Scripps Research Institute.
# READ MORE
# Eric Topol, M.D.
# Founder and Director, Scripps Translational Science Institute
# Anne Wojcicki co-founded 23andMe in 2006 after a decade in health care investing focusing on biotechnology companies.
# READ MORE
# Anne Wojcicki
# Co-Founder and CEO, 23andMe
# Venue
# The Roosevelt Hotel
# The Roosevelt Hotel
# 45 E 45th Street
# New York, NY 10017
# There is a special CNBC room rate of $219 per night, plus tax.
# To reserve a room with this rate, please call the Roosevelt Hotel directly at 212-661-9600.
# Please note this special rate will be honored until February 27, 2018 or until the limited block has been filled.
# Click here for hotel directions.
# Sponsors
# CONTACT
# Are you looking for more information?
# Please contact the following:
# • For sponsorship opportunities, contact Alisha Hathaway
# • For speaker and editorial inquiries, contact Maneet Ahuja
# • For press and media inquiries, contact Jennifer Dauble
# • For other questions, contact healthyreturns@cnbc.com
# Stocks rose to record highs on Friday after some of the major financial companies in the U.S. reported strong quarterly results.
# The Dow Jones industrial average rose 228.46 points to close at 25,803.19, an all-time high.
# J.P. Morgan Chase was among the best-performing stocks in the index, rising 1.7 percent.
# The S&P 500 also reached a record high, climbing 0.7 percent to 2,786.24 with energy and consumer discretionary as the best-performing sectors.
# Energy stocks got a boost from rising oil prices.
# The index is also enjoying its best 10-day start to a year since 2003.
# In that time period, the S&P 500 is up 4.2 percent.
# It gained 5.9 percent during the first 10 days of 2003.
# "There is optimism in the market," but there is also uncertainty about this rally, said Cooper Abbott, chairman of Carillon Tower Advisers.
# That level of uncertainty can be good for the market because it "dampens expectations."
# The Nasdaq composite finished 0.7 percent higher at 7,261.06.
# Amazon shares rose 2.2 percent and broke above $1,300 for the first time.
# J.P. Morgan Chase, BlackRock and Wells Fargo all reported better-than-expected quarterly results.
# Brendan McDermid | Reuters
# Traders work on the floor of the New York Stock Exchange.
# S&P 500 profits are expected to have risen 11.2 percent in the fourth quarter of last year.
# All 11 S&P 500 sectors, meanwhile, are expected to post increases in both earnings and revenue, according to FactSet.
# This would be the first time since 2011 that all the sectors in the S&P 500 posted sales and profit growth for the same quarter.
# Stocks have carried over the momentum from 2017 into the new year thus far.
# The S&P 500 and Nasdaq have closed lower only once this year, while the Dow has fallen just twice.
# For 2018, the major averages are up at least 3.5 percent entering Friday's session.
# For the week, they posted gains of at least 1.6 percent.
# The Dow outperformed the Nasdaq and S&P 500 this week, gaining 2
# percent, as Boeing shares have soared 8.9 percent.
# "The most important dynamic to focus on in the market is growth," said Sandip Bhagat, chief investment officer at Whittier Trust.
# He acknowledged that risks to the rally do exist, but added: "They pale in comparison to the economic growth we're seeing."
# Recent data suggests the U.S. economy is picking up steam.
# The Labor Department said its Consumer Price Index excluding the volatile food and energy components rose 0.3 percent last month.
# That was the biggest advance in the so-called core CPI since January.
# Treasury yields ticked higher following the data release.
# The two-year yield broke above 2 percent for the first time since September 2008.
# It traded at 2.01 percent.
# —Reuters contributed to this report.
# Getty Images
# A trader wears a DOW 24,000 hat as he works on the floor of the New York Stock Exchange, (NYSE) as the Dow Jones Industrial Average crosses 25,000 on Jan. 4ht, 2018 for the first time.
# U.S. stock index futures gave back some of their gains on Friday after the release of key inflation data.
# Dow Jones industrial average futures traded 72 points higher; they had risen more than 100 points earlier in the session.
# S&P 500 futurews were down half a point and Nasdaq 100 futures fell 21 points.
# The Labor Department said its Consumer Price Index excluding the volatile food and energy components rose 0.3 percent last month.
# That was the biggest advance in the so-called core CPI since January.
# Equity futures had risen after Wells Fargo and J.P. Morgan Chase reported better-than-expected quarterly results.
# BlackRock also posted results that beat expectations.
# On Thursday, the Dow hit an all-time high, with the index rising more than 200 points by the close.
# The state of the U.S. economy and tax reform is set to be of key importance on Friday as major U.S. banks are set to report.
# Markets have been on the rise as of late, after President Donald Trump signed a bill in December to slash the corporate tax rate from 35 percent to 21 percent.
# Meantime, investors will keep a close eye on bond markets, after investors fretted over the risk of China halting its Treasury bond purchases.
# Vote
# Vote to see results
# Total Votes:
# Not a Scientific Survey.
# Results may not total 100% due to rounding.
# On Wednesday, Bloomberg News reported, citing people familiar with the matter, that officials in Beijing had recommended that China's government lowers — or even potentially ceases — its buying of U.S. sovereign debt.
# However, China's currency regulator has since refuted the report.
# On the U.S. central bank front, Boston Fed President Eric Rosengren is expected to be in California, where he's set to give a keynote address at the Money, Models, and Digital Innovation conference in San Diego.
# Meantime, Philadelphia Fed President Patrick Harker is expected to be present at the Central Bucks Chamber of Commerce Economic Luncheon in Pennsylvania.
# Overseas, coalition party leaders in Germany have reached a breakthrough in talks to form a new government.
# German Chancellor Angela Merkel had entered into talks with a rival party in a last-ditch effort to form a coalition government.
# This comes after months of political uncertainty.
# —Reuters contributed to this report.
# Oleg Popov | Reuters
# The stock market will enjoy a "Made in America" boom this year thanks to a slew of policies spearheaded by the Trump administration, according to a Wall Street investment bank.
# Some of the nation's largest industrial and steel companies will rally under President Donald Trump's focus on domestic prosperity, spelling even more upside for investors, according to Jefferies.
# With the U.S. thinking about leaving NAFTA, "new tax incentives to repatriate profits in place and the dollar weak, the ingredients for a domestic investment boom are in place," analyst Sean Darby wrote Thursday.
# "While the corporate sector is obviously euphoric over the tax changes, it is not often highlighted that it has improved U.S.'s competitive position."
# show chapters
# These NAFTA-sensitive stocks are moving on trade talks
# 7:58
# AM ET Thu, 11 Jan 2018 |
# 02:16
# Trump and Republican lawmakers clinched a major legislative victory by passing the Tax Cuts and Jobs Act in late 2017, reducing the corporate tax rate to 21 percent and offering new incentives for companies to repatriate profits.
# The GOP hopes that by amending the tax code the economy will surge further, and drive most investing dollars into the U.S.
# But even as some of the country's industrial titans catch a tax break, the fate of some of the country's most iconic trade agreements hang in the balance.
# Trump is currently debating U.S. participation in NAFTA, the iconic 24-year-old trade pact with Canada and Mexico.
# ...
# [('That', 'DT'), ('was', 'VBD'), ('the', 'DT'), ('biggest', 'JJS'), ('advance', 'NN'), ('in', 'IN'), ('the', 'DT'), ('so-called', 'JJ'), ('core', 'NN'), ('CPI', 'NNP'), ('since', 'IN'), ('January', 'NNP'), ('.', '.')]
# [('Equity', 'NN'), ('futures', 'NNS'), ('had', 'VBD'), ('risen', 'VBN'), ('after', 'IN'), ('Wells', 'NNP'), ('Fargo', 'NNP'), ('and', 'CC'), ('J.P.', 'NNP'), ('Morgan', 'NNP'), ('Chase', 'NNP'), ('reported', 'VBD'), ('better-than-expected', 'JJ'), ('quarterly', 'JJ'), ('results', 'NNS'), ('.', '.')]
# [('BlackRock', 'NNP'), ('also', 'RB'), ('posted', 'VBD'), ('results', 'NNS'), ('that', 'IN'), ('beat', 'JJ'), ('expectations', 'NNS'), ('.', '.')]
# [('On', 'IN'), ('Thursday', 'NNP'), (',', ','), ('the', 'DT'), ('Dow', 'NNP'), ('hit', 'VBD'), ('an', 'DT'), ('all-time', 'JJ'), ('high', 'NN'), (',', ','), ('with', 'IN'), ('the', 'DT'), ('index', 'NN'), ('rising', 'VBG'), ('more', 'JJR'), ('than', 'IN'), ('200', 'CD'), ('points', 'NNS'), ('by', 'IN'), ('the', 'DT'), ('close', 'NN'), ('.', '.')]
# [('The', 'DT'), ('state', 'NN'), ('of', 'IN'), ('the', 'DT'), ('U.S.', 'NNP'), ('economy', 'NN'), ('and', 'CC'), ('tax', 'NN'), ('reform', 'NN'), ('is', 'VBZ'), ('set', 'VBN'), ('to', 'TO'), ('be', 'VB'), ('of', 'IN'), ('key', 'JJ'), ('importance', 'NN'), ('on', 'IN'), ('Friday', 'NNP'), ('as', 'IN'), ('major', 'JJ'), ('U.S.', 'NNP'), ('banks', 'NNS'), ('are', 'VBP'), ('set', 'VBN'), ('to', 'TO'), ('report', 'VB'), ('.', '.')]
# [('Markets', 'NNS'), ('have', 'VBP'), ('been', 'VBN'), ('on', 'IN'), ('the', 'DT'), ('rise', 'NN'), ('as', 'IN'), ('of', 'IN'), ('late', 'JJ'), (',', ','), ('after', 'IN'), ('President', 'NNP'), ('Donald', 'NNP'), ('Trump', 'NNP'), ('signed', 'VBD'), ('a', 'DT'), ('bill', 'NN'), ('in', 'IN'), ('December', 'NNP'), ('to', 'TO'), ('slash', 'VB'), ('the', 'DT'), ('corporate', 'JJ'), ('tax', 'NN'), ('rate', 'NN'), ('from', 'IN'), ('35', 'CD'), ('percent', 'NN'), ('to', 'TO'), ('21', 'CD'), ('percent', 'NN'), ('.', '.')]
# [('Meantime', 'RB'), (',', ','), ('investors', 'NNS'), ('will', 'MD'), ('keep', 'VB'), ('a', 'DT'), ('close', 'JJ'), ('eye', 'NN'), ('on', 'IN'), ('bond', 'NN'), ('markets', 'NNS'), (',', ','), ('after', 'IN'), ('investors', 'NNS'), ('fretted', 'VBD'), ('over', 'IN'), ('the', 'DT'), ('risk', 'NN'), ('of', 'IN'), ('China', 'NNP'), ('halting', 'VBG'), ('its', 'PRP$'), ('Treasury', 'NNP'), ('bond', 'NN'), ('purchases', 'NNS'), ('.', '.')]
# [('Vote', 'NNP'), ('Vote', 'NNP'), ('to', 'TO'), ('see', 'VB'), ('results', 'NNS'), ('Total', 'JJ'), ('Votes', 'NNS'), (':', ':'), ('Not', 'RB'), ('a', 'DT'), ('Scientific', 'NNP'), ('Survey', 'NNP'), ('.', '.')]
# [('Results', 'NNS'), ('may', 'MD'), ('not', 'RB'), ('total', 'VB'), ('100', 'CD'), ('%', 'NN'), ('due', 'JJ'), ('to', 'TO'), ('rounding', 'VBG'), ('.', '.')]
# [('On', 'IN'), ('Wednesday', 'NNP'), (',', ','), ('Bloomberg', 'NNP'), ('News', 'NNP'), ('reported', 'VBD'), (',', ','), ('citing', 'VBG'), ('people', 'NNS'), ('familiar', 'JJ'), ('with', 'IN'), ('the', 'DT'), ('matter', 'NN'), (',', ','), ('that', 'WDT'), ('officials', 'NNS'), ('in', 'IN'), ('Beijing', 'NNP'), ('had', 'VBD'), ('recommended', 'VBN'), ('that', 'IN'), ('China', 'NNP'), ("'s", 'POS'), ('government', 'NN'), ('lowers', 'NNS'), ('—', 'VBP'), ('or', 'CC'), ('even', 'RB'), ('potentially', 'RB'), ('ceases', 'VBZ'), ('—', 'VB'), ('its', 'PRP$'), ('buying', 'NN'), ('of', 'IN'), ('U.S.', 'NNP'), ('sovereign', 'JJ'), ('debt', 'NN'), ('.', '.')]
# [('However', 'RB'), (',', ','), ('China', 'NNP'), ("'s", 'POS'), ('currency', 'NN'), ('regulator', 'NN'), ('has', 'VBZ'), ('since', 'IN'), ('refuted', 'VBN'), ('the', 'DT'), ('report', 'NN'), ('.', '.')]
# [('On', 'IN'), ('the', 'DT'), ('U.S.', 'NNP'), ('central', 'JJ'), ('bank', 'NN'), ('front', 'NN'), (',', ','), ('Boston', 'NNP'), ('Fed', 'NNP'), ('President', 'NNP'), ('Eric', 'NNP'), ('Rosengren', 'NNP'), ('is', 'VBZ'), ('expected', 'VBN'), ('to', 'TO'), ('be', 'VB'), ('in', 'IN'), ('California', 'NNP'), (',', ','), ('where', 'WRB'), ('he', 'PRP'), ("'s", 'VBZ'), ('set', 'VBN'), ('to', 'TO'), ('give', 'VB'), ('a', 'DT'), ('keynote', 'NN'), ('address', 'NN'), ('at', 'IN'), ('the', 'DT'), ('Money', 'NNP'), (',', ','), ('Models', 'NNP'), (',', ','), ('and', 'CC'), ('Digital', 'NNP'), ('Innovation', 'NNP'), ('conference', 'NN'), ('in', 'IN'), ('San', 'NNP'), ('Diego', 'NNP'), ('.', '.')]
# [('Meantime', 'RB'), (',', ','), ('Philadelphia', 'NNP'), ('Fed', 'NNP'), ('President', 'NNP'), ('Patrick', 'NNP'), ('Harker', 'NNP'), ('is', 'VBZ'), ('expected', 'VBN'), ('to', 'TO'), ('be', 'VB'), ('present', 'JJ'), ('at', 'IN'), ('the', 'DT'), ('Central', 'NNP'), ('Bucks', 'NNP'), ('Chamber', 'NNP'), ('of', 'IN'), ('Commerce', 'NNP'), ('Economic', 'NNP'), ('Luncheon', 'NNP'), ('in', 'IN'), ('Pennsylvania', 'NNP'), ('.', '.')]
# [('Overseas', 'RB'), (',', ','), ('coalition', 'NN'), ('party', 'NN'), ('leaders', 'NNS'), ('in', 'IN'), ('Germany', 'NNP'), ('have', 'VBP'), ('reached', 'VBN'), ('a', 'DT'), ('breakthrough', 'NN'), ('in', 'IN'), ('talks', 'NNS'), ('to', 'TO'), ('form', 'VB'), ('a', 'DT'), ('new', 'JJ'), ('government', 'NN'), ('.', '.')]
# [('German', 'JJ'), ('Chancellor', 'NNP'), ('Angela', 'NNP'), ('Merkel', 'NNP'), ('had', 'VBD'), ('entered', 'VBN'), ('into', 'IN'), ('talks', 'NNS'), ('with', 'IN'), ('a', 'DT'), ('rival', 'JJ'), ('party', 'NN'), ('in', 'IN'), ('a', 'DT'), ('last-ditch', 'JJ'), ('effort', 'NN'), ('to', 'TO'), ('form', 'VB'), ('a', 'DT'), ('coalition', 'NN'), ('government', 'NN'), ('.', '.')]
# [('This', 'DT'), ('comes', 'VBZ'), ('after', 'IN'), ('months', 'NNS'), ('of', 'IN'), ('political', 'JJ'), ('uncertainty', 'NN'), ('.', '.')]
# [('—Reuters', 'NNS'), ('contributed', 'VBD'), ('to', 'TO'), ('this', 'DT'), ('report', 'NN'), ('.', '.')]
# [('Oleg', 'NNP'), ('Popov', 'NNP'), ('|', 'NNP'), ('Reuters', 'NNP'), ('The', 'DT'), ('stock', 'NN'), ('market', 'NN'), ('will', 'MD'), ('enjoy', 'VB'), ('a', 'DT'), ('``', '``'), ('Made', 'NNP'), ('in', 'IN'), ('America', 'NNP'), ("''", "''"), ('boom', 'NN'), ('this', 'DT'), ('year', 'NN'), ('thanks', 'VBZ'), ('to', 'TO'), ('a', 'DT'), ('slew', 'NN'), ('of', 'IN'), ('policies', 'NNS'), ('spearheaded', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('Trump', 'NNP'), ('administration', 'NN'), (',', ','), ('according', 'VBG'), ('to', 'TO'), ('a', 'DT'), ('Wall', 'NNP'), ('Street', 'NNP'), ('investment', 'NN'), ('bank', 'NN'), ('.', '.')]
# [('Some', 'DT'), ('of', 'IN'), ('the', 'DT'), ('nation', 'NN'), ("'s", 'POS'), ('largest', 'JJS'), ('industrial', 'JJ'), ('and', 'CC'), ('steel', 'NN'), ('companies', 'NNS'), ('will', 'MD'), ('rally', 'VB'), ('under', 'IN'), ('President', 'NNP'), ('Donald', 'NNP'), ('Trump', 'NNP'), ("'s", 'POS'), ('focus', 'NN'), ('on', 'IN'), ('domestic', 'JJ'), ('prosperity', 'NN'), (',', ','), ('spelling', 'VBG'), ('even', 'RB'), ('more', 'RBR'), ('upside', 'JJ'), ('for', 'IN'), ('investors', 'NNS'), (',', ','), ('according', 'VBG'), ('to', 'TO'), ('Jefferies', 'NNPS'), ('.', '.')]
# [('With', 'IN'), ('the', 'DT'), ('U.S.', 'NNP'), ('thinking', 'NN'), ('about', 'IN'), ('leaving', 'VBG'), ('NAFTA', 'NNP'), (',', ','), ('``', '``'), ('new', 'JJ'), ('tax', 'NN'), ('incentives', 'NNS'), ('to', 'TO'), ('repatriate', 'VB'), ('profits', 'NNS'), ('in', 'IN'), ('place', 'NN'), ('and', 'CC'), ('the', 'DT'), ('dollar', 'NN'), ('weak', 'JJ'), (',', ','), ('the', 'DT'), ('ingredients', 'NNS'), ('for', 'IN'), ('a', 'DT'), ('domestic', 'JJ'), ('investment', 'NN'), ('boom', 'NN'), ('are', 'VBP'), ('in', 'IN'), ('place', 'NN'), (',', ','), ("''", "''"), ('analyst', 'NN'), ('Sean', 'NNP'), ('Darby', 'NNP'), ('wrote', 'VBD'), ('Thursday', 'NNP'), ('.', '.')]
# [('``', '``'), ('While', 'IN'), ('the', 'DT'), ('corporate', 'JJ'), ('sector', 'NN'), ('is', 'VBZ'), ('obviously', 'RB'), ('euphoric', 'JJ'), ('over', 'IN'), ('the', 'DT'), ('tax', 'NN'), ('changes', 'NNS'), (',', ','), ('it', 'PRP'), ('is', 'VBZ'), ('not', 'RB'), ('often', 'RB'), ('highlighted', 'VBN'), ('that', 'IN'), ('it', 'PRP'), ('has', 'VBZ'), ('improved', 'VBN'), ('U.S.', 'NNP'), ("'s", 'POS'), ('competitive', 'JJ'), ('position', 'NN'), ('.', '.'), ("''", "''")]
# [('show', 'NN'), ('chapters', 'NNS'), ('These', 'DT'), ('NAFTA-sensitive', 'JJ'), ('stocks', 'NNS'), ('are', 'VBP'), ('moving', 'VBG'), ('on', 'IN'), ('trade', 'NN'), ('talks', 'NNS'), ('7:58', 'CD'), ('AM', 'NNP'), ('ET', 'NNP'), ('Thu', 'NNP'), (',', ','), ('11', 'CD'), ('Jan', 'NNP'), ('2018', 'CD'), ('|', 'NNP'), ('02:16', 'CD'), ('Trump', 'NNP'), ('and', 'CC'), ('Republican', 'NNP'), ('lawmakers', 'NNS'), ('clinched', 'VBD'), ('a', 'DT'), ('major', 'JJ'), ('legislative', 'JJ'), ('victory', 'NN'), ('by', 'IN'), ('passing', 'VBG'), ('the', 'DT'), ('Tax', 'NNP'), ('Cuts', 'NNP'), ('and', 'CC'), ('Jobs', 'NNP'), ('Act', 'NNP'), ('in', 'IN'), ('late', 'JJ'), ('2017', 'CD'), (',', ','), ('reducing', 'VBG'), ('the', 'DT'), ('corporate', 'JJ'), ('tax', 'NN'), ('rate', 'NN'), ('to', 'TO'), ('21', 'CD'), ('percent', 'NN'), ('and', 'CC'), ('offering', 'VBG'), ('new', 'JJ'), ('incentives', 'NNS'), ('for', 'IN'), ('companies', 'NNS'), ('to', 'TO'), ('repatriate', 'VB'), ('profits', 'NNS'), ('.', '.')]
# [('The', 'DT'), ('GOP', 'NNP'), ('hopes', 'VBZ'), ('that', 'IN'), ('by', 'IN'), ('amending', 'VBG'), ('the', 'DT'), ('tax', 'NN'), ('code', 'VBZ'), ('the', 'DT'), ('economy', 'NN'), ('will', 'MD'), ('surge', 'VB'), ('further', 'RBR'), (',', ','), ('and', 'CC'), ('drive', 'VBP'), ('most', 'RBS'), ('investing', 'JJ'), ('dollars', 'NNS'), ('into', 'IN'), ('the', 'DT'), ('U.S', 'NNP'), ('.', '.')]
# [('But', 'CC'), ('even', 'RB'), ('as', 'IN'), ('some', 'DT'), ('of', 'IN'), ('the', 'DT'), ('country', 'NN'), ("'s", 'POS'), ('industrial', 'JJ'), ('titans', 'NNS'), ('catch', 'VBP'), ('a', 'DT'), ('tax', 'NN'), ('break', 'NN'), (',', ','), ('the', 'DT'), ('fate', 'NN'), ('of', 'IN'), ('some', 'DT'), ('of', 'IN'), ('the', 'DT'), ('country', 'NN'), ("'s", 'POS'), ('most', 'RBS'), ('iconic', 'JJ'), ('trade', 'NN'), ('agreements', 'NNS'), ('hang', 'VBP'), ('in', 'IN'), ('the', 'DT'), ('balance', 'NN'), ('.', '.')]
# [('Trump', 'NNP'), ('is', 'VBZ'), ('currently', 'RB'), ('debating', 'VBG'), ('U.S.', 'NNP'), ('participation', 'NN'), ('in', 'IN'), ('NAFTA', 'NNP'), (',', ','), ('the', 'DT'), ('iconic', 'JJ'), ('24-year-old', 'JJ'), ('trade', 'NN'), ('pact', 'NN'), ('with', 'IN'), ('Canada', 'NNP'), ('and', 'CC'), ('Mexico', 'NNP'), ('.', '.')]
# [('Should', 'MD'), ('the', 'DT'), ('U.S.', 'NNP'), ('pull', 'VBZ'), ('out', 'IN'), ('of', 'IN'), ('the', 'DT'), ('agreement', 'NN'), (',', ','), ('incentives', 'VBZ'), ('to', 'TO'), ('``', '``'), ('off-shore', 'JJ'), ("''", "''"), ('factories', 'NNS'), ('could', 'MD'), ('diminish', 'VB'), ('.', '.')]
# [('``', '``'), ('The', 'DT'), ('NAFTA', 'NNP'), ('trade', 'NN'), ('agreement', 'NN'), ('encouraged', 'VBD'), ("'off-shoring", 'VBG'), ("'", "''"), ('or', 'CC'), ('the', 'DT'), ('placement', 'NN'), ('of', 'IN'), ('U.S.', 'NNP'), ('manufacturing', 'NN'), ('in', 'IN'), ('its', 'PRP$'), ('neighbors', 'NNS'), ('due', 'JJ'), ('to', 'TO'), ('better', 'RBR'), ('labor', 'NN'), ('laws', 'NNS'), (',', ','), ('cheaper', 'JJR'), ('exchange', 'NN'), ('rates', 'NNS'), ('and/or', 'VBP'), ('lower', 'JJR'), ('wages', 'NNS'), (',', ','), ("''", "''"), ('added', 'VBD'), ('Darby', 'NNP'), ('.', '.')]
# [('``', '``'), ('Coincidentally', 'RB'), (',', ','), ('next', 'JJ'), ('Tuesday', 'NNP'), (',', ','), ('the', 'DT'), ('U.S.', 'NNP'), ('Department', 'NNP'), ('of', 'IN'), ('Commerce', 'NNP'), ('is', 'VBZ'), ('expected', 'VBN'), ('to', 'TO'), ('provide', 'VB'), ('formal', 'JJ'), ('recommendations', 'NNS'), ('to', 'TO'), ('the', 'DT'), ('President', 'NNP'), ('regarding', 'VBG'), ('possible', 'JJ'), ('action', 'NN'), ('to', 'TO'), ('combat', 'VB'), ('U.S.', 'NNP'), ('steel', 'NN'), ('imports', 'NNS'), ('on', 'IN'), ('national', 'JJ'), ('security', 'NN'), ('grounds', 'NNS'), ('.', '.'), ("''", "''")]
# [('Such', 'JJ'), ('decisions', 'NNS'), ('by', 'IN'), ('the', 'DT'), ('Trump', 'NNP'), ('administration', 'NN'), ('are', 'VBP'), ('likely', 'JJ'), ('already', 'RB'), ('having', 'VBG'), ('an', 'DT'), ('effect', 'NN'), ('on', 'IN'), ('the', 'DT'), ('business', 'NN'), ('world', 'NN'), ('.', '.')]
# [('The', 'DT'), ('Dow', 'NNP'), ('Jones', 'NNP'), ('industrial', 'JJ'), ('average', 'NN'), ('added', 'VBD'), ('more', 'JJR'), ('than', 'IN'), ('150', 'CD'), ('points', 'NNS'), ('to', 'TO'), ('claim', 'VB'), ('another', 'DT'), ('all-time', 'JJ'), ('high', 'JJ'), ('Thursday', 'NNP'), ('while', 'IN'), ('both', 'CC'), ('the', 'DT'), ('S', 'NNP'), ('&', 'CC'), ('P', 'NNP'), ('500', 'CD'), ('and', 'CC'), ('the', 'DT'), ('Nasdaq', 'NNP'), ('hit', 'NN'), ('records', 'NNS'), ('.', '.')]
# [('The', 'DT'), ('gains', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('Dow', 'NNP'), ('have', 'VBP'), ('largely', 'RB'), ('stemmed', 'VBN'), ('from', 'IN'), ('industrial', 'JJ'), ('giants', 'NNS'), ('Boeing', 'NNP'), (',', ','), ('Chevron', 'NNP'), ('and', 'CC'), ('Caterpillar', 'NNP'), (',', ','), ('seen', 'VBN'), ('as', 'IN'), ('key', 'JJ'), ('beneficiaries', 'NNS'), ('from', 'IN'), ('the', 'DT'), ('tax', 'NN'), ('changes', 'NNS'), ('.', '.')]
# [('The', 'DT'), ('materials', 'NNS'), ('sector', 'NN'), (',', ','), ('including', 'VBG'), ('the', 'DT'), ('nation', 'NN'), ("'s", 'POS'), ('largest', 'JJS'), ('steel', 'NN'), ('manufacturers', 'NNS'), (',', ','), ('should', 'MD'), ('also', 'RB'), ('benefit', 'VB'), ('from', 'IN'), ('more', 'RBR'), ('protective', 'JJ'), ('policies', 'NNS'), (',', ','), ('said', 'VBD'), ('Darby', 'NNP'), (',', ','), ('even', 'RB'), ('as', 'IN'), ('factory', 'NN'), ('activity', 'NN'), ('climbs', 'NN'), ('.', '.')]
# [('``', '``'), ('The', 'DT'), ('bottom', 'JJ'), ('line', 'NN'), ('is', 'VBZ'), ('that', 'IN'), ('the', 'DT'), ('backdrop', 'NN'), ('for', 'IN'), ('the', 'DT'), ('U.S.', 'NNP'), ('materials', 'NNS'), ('sector', 'NN'), ('is', 'VBZ'), ('improving', 'VBG'), (',', ','), ("''", "''"), ('wrote', 'VBD'), ('Darby', 'NNP'), ('.', '.')]
# [('``', '``'), ('The', 'DT'), ('cocktail', 'NN'), ('of', 'IN'), ('tax', 'NN'), ('reform', 'NN'), (',', ','), ('NAFTA', 'NNP'), (',', ','), ('steel', 'NN'), ('tariffs', 'NNS'), (',', ','), ('and', 'CC'), ('booming', 'VBG'), ('investment', 'NN'), ('intentions', 'NNS'), ('comes', 'VBZ'), ('at', 'IN'), ('a', 'DT'), ('time', 'NN'), ('when', 'WRB'), ('the', 'DT'), ('ISM', 'NNP'), ('manufacturing', 'NN'), ('index', 'NN'), ('is', 'VBZ'), ('surging', 'VBG'), ('.', '.'), ("''", "''")]
# [('Names', 'NNS'), ('like', 'IN'), ('United', 'NNP'), ('States', 'NNPS'), ('Steel', 'NNP'), (',', ','), ('Commercial', 'JJ'), ('Metals', 'NNS'), ('and', 'CC'), ('Steel', 'NNP'), ('Dynamics', 'NNS'), ('are', 'VBP'), ('the', 'DT'), ('``', '``'), ('best', 'JJS'), ('positioned', 'VBN'), ("''", "''"), ('to', 'TO'), ('benefit', 'VB'), ('from', 'IN'), ('steel', 'NN'), ('tariffs', 'NNS'), (',', ','), ('Darby', 'NNP'), ('said', 'VBD'), (',', ','), ('all', 'DT'), ('of', 'IN'), ('which', 'WDT'), ('have', 'VBP'), ('buy', 'VBN'), ('ratings', 'NNS'), ('from', 'IN'), ('the', 'DT'), ('investment', 'NN'), ('bank', 'NN'), ('.', '.')]
# [('The', 'DT'), ('companies', 'NNS'), ('were', 'VBD'), ('up', 'RB'), ('0.75', 'CD'), ('percent', 'NN'), (',', ','), ('2.1', 'CD'), ('percent', 'NN'), (',', ','), ('and', 'CC'), ('1.7', 'CD'), ('percent', 'NN'), ('respectively', 'RB'), ('during', 'IN'), ('Thursday', 'NNP'), ('trading', 'NN'), ('.', '.')]
# [('Disclaimer', 'NNP'), ('WATCH', 'NNP'), (':', ':'), ('US', 'PRP'), ('playing', 'VBG'), ("'Russian", 'JJ'), ('roulette', 'NN'), ("'", "''"), ('with', 'IN'), ('Canada-NAFTA', 'JJ'), ('talks', 'NNS'), ('show', 'VBP'), ('chapters', 'NNS'), ('US', 'NNP'), ('playing', 'VBG'), ("'Russian", 'JJ'), ('roulette', 'NN'), ("'", "''"), ('in', 'IN'), ('Canada-NAFTA', 'JJ'), ('talks', 'NNS'), (':', ':'), ('Former', 'NNP'), ('US', 'NNP'), ('Ambassador', 'NNP'), ('to', 'TO'), ('Canada', 'NNP'), ('7:22', 'CD'), ('AM', 'NNP'), ('ET', 'NNP'), ('Thu', 'NNP'), (',', ','), ('11', 'CD'), ('Jan', 'NNP'), ('2018', 'CD'), ('|', 'VBD'), ('02:39', 'CD')]

# %%
# LIST OF SENTENCES FOR TEXTS
print(sent_list)
# Out:
# ['ABOUT\nSPEAKERS\nAGENDA\nADVISORY BOARD\nVENUE\nSPONSORS\nCONTACT\nAbout\nHow innovators and investors are working with patients and providers to develop dynamic new solutions and create healthy returns.', 'CNBC presents a one-day event at NYC’s Roosevelt Hotel that brings together top health care investors, CEOs and technologists to explore the innovations that will drive better outcomes, financially and clinically.', 'Every health care company seeks to scale the best technology and develop profitable ways to cover the massive cost of research and development, investors are looking for actionable intelligence on who’s breaking through, and patients are hungry for affordable and effective care.', 'Healthy Returns is a convening of leaders who are improving patient outcomes, maximizing innovation, building great new companies and reinventing incumbents.', 'Led by CNBC’s anchors and reporters and with input from a world-class advisory board, Healthy Returns will hone in on groundbreaking ideas that will transform the health care industry, cutting through the noise and weeding out the "sales pitch."', 'Attendees should expect to walk away with smart strategies and actionable insights from people who are shaping the industry, including:\n• Investment ideas and intelligence from the biggest and best health care hedge funds, venture capitalists and portfolio managers.', '• Strategic perspective from top health care CEOs.', '• An early, inside look at groundbreaking, transformative innovations.', '• Unique networking opportunities to connect with leaders in multiple disciplines – investors, executives, entrepreneurs and innovators.', 'Who should attend:\nHealth care investors, VCs, C-Suite executives from the biotech, pharma, health care and life sciences industries, health care IT BDMs.', 'Speakers\nMore speakers will be announced soon.', 'Tap or click a card to reveal more information:\nAmy Abernethy M.D., PhD, serves as chief medical officer, chief scientific officer and senior vice president, oncology of Flatiron Health.', 'READ MORE\nAmy Abernethy M.D., PhDChief Medical Officer, Chief Scientific Officer, Senior Vice President, Flatiron Health\nBill George is an American businessman and academic.', 'He is professor of Management Practice and a Henry B. Arthur Fellow of Ethics, at Harvard Business School.', 'READ MORE\nBill GeorgeSenior Fellow, Harvard Business School and Former Chairman and CEO, Medtronic\nDr. Gottlieb is the 23rd commissioner of the Food and Drug Administration.', 'READ MORE\nScott Gottlieb, M.D.Commissioner of Food and Drugs, U.S. FDA\nFred Hassan is a special limited partner and managing director with the private equity firm, Warburg Pincus and chairman of Caret Group.', 'READ MORE\nFred HassanSpecial Limited Partner, Warburg Pincus and Chairman, Caret Group\nLeonard S. Schleifer, M.D., PhD, is the founder, president and chief executive officer of Regeneron Pharmaceuticals.', 'READ MORE\nLeonard S. Schleifer, M.D., PhD\nFounder, President and CEO, Regeneron Pharmaceuticals\nAgenda\nAgenda coming soon\nAdvisory Board\nTap or click a card to reveal more information:\nAmy Abernethy M.D., PhD, serves as chief medical officer, chief scientific officer and senior vice president, oncology of Flatiron Health.', 'READ MORE\nAmy Abernethy M.D., PhD\nChief Medical Officer, Chief Scientific Officer, Senior Vice President, Flatiron Health\nDr. Coles is the chairman and chief executive officer of Yumanity Therapeutics, a biotechnology company.', 'He also serves as chairman and chief executive officer of TRATE Enterprises LLC.', 'READ MORE\nTony Coles, M.D.', 'Chairman and CEO, Yumanity Therapeutics\nDr. Cosgrove is president and chief executive officer of Cleveland Clinic, presiding over an $8 billion health-care system.', 'READ MORE\nDelos M. Cosgrove, M.D.', "President and CEO, Cleveland Clinic\nDr. Kenneth L. Davis, is president and chief executive officer\nof the Mount Sinai Health System in New York City, one of the  ...

# %%
#TOKENIZED WORD LIST FOR TEXTS
print(word_list)
# Out:
# [['ABOUT', 'SPEAKERS', 'AGENDA', 'ADVISORY', 'BOARD', 'VENUE', 'SPONSORS', 'CONTACT', 'About', 'How', 'innovators', 'and', 'investors', 'are', 'working', 'with', 'patients', 'and', 'providers', 'to', 'develop', 'dynamic', 'new', 'solutions', 'and', 'create', 'healthy', 'returns', '.'], ['CNBC', 'presents', 'a', 'one-day', 'event', 'at', 'NYC', '’', 's', 'Roosevelt', 'Hotel', 'that', 'brings', 'together', 'top', 'health', 'care', 'investors', ',', 'CEOs', 'and', 'technologists', 'to', 'explore', 'the', 'innovations', 'that', 'will', 'drive', 'better', 'outcomes', ',', 'financially', 'and', 'clinically', '.'], ['Every', 'health', 'care', 'company', 'seeks', 'to', 'scale', 'the', 'best', 'technology', 'and', 'develop', 'profitable', 'ways', 'to', 'cover', 'the', 'massive', 'cost', 'of', 'research', 'and', 'development', ',', 'investors', 'are', 'looking', 'for', 'actionable', 'intelligence', 'on', 'who', '’', 's', 'breaking', 'through', ',', 'and', 'patients', 'are', 'hungry', 'for', 'affordable', 'and', 'effective', 'care', '.'], ['Healthy', 'Returns', 'is', 'a', 'convening', 'of', 'leaders', 'who', 'are', 'improving', 'patient', 'outcomes', ',', 'maximizing', 'innovation', ',', 'building', 'great', 'new', 'companies', 'and', 'reinventing', 'incumbents', '.'], ['Led', 'by', 'CNBC', '’', 's', 'anchors', 'and', 'reporters', 'and', 'with', 'input', 'from', 'a', 'world-class', 'advisory', 'board', ',', 'Healthy', 'Returns', 'will', 'hone', 'in', 'on', 'groundbreaking', 'ideas', 'that', 'will', 'transform', 'the', 'health', 'care', 'industry', ',', 'cutting', 'through', 'the', 'noise', 'and', 'weeding', 'out', 'the', '``', 'sales', 'pitch', '.', "''"], ['Attendees', 'should', 'expect', 'to', 'walk', 'away', 'with', 'smart', 'strategies', 'and', 'actionable', 'insights', 'from', 'people', 'who', 'are', 'shaping', 'the', 'industry', ',', 'including', ':', '•', 'Investment', 'ideas', 'and', 'intelligence', 'from', 'the', 'biggest', 'and', 'best', 'health', 'care', 'hedge', 'funds', ',', 'venture', 'capitalists', 'and', 'portfolio', 'managers', '.'], ['•', 'Strategic', 'perspective', 'from', 'top', 'health', 'care', 'CEOs', '.'], ['•', 'An', 'early', ',', 'inside', 'look', 'at', 'groundbreaking', ',', 'transformative', 'innovations', '.'], ['•', 'Unique', 'networking', 'opportunities', 'to', 'connect', 'with', 'leaders', 'in', 'multiple', 'disciplines', '–', 'investors', ',', 'executives', ',', 'entrepreneurs', 'and', 'innovators', '.'], ['Who', 'should', 'attend', ':', 'Health', 'care', 'investors', ',', 'VCs', ',', 'C-Suite', 'executives', 'from', 'the', 'biotech', ',', 'pharma', ',', 'health', 'care', 'and', 'life', 'sciences', 'industries', ',', 'health', 'care', 'IT', 'BDMs', '.'], ['Speakers', 'More', 'speakers', 'will', 'be', 'announced', 'soon', '.'], ['Tap', 'or', 'click', 'a', 'card', 'to', 'reveal', 'more', 'information', ':', 'Amy', 'Abernethy', 'M.D.', ',', 'PhD', ',', 'serves', 'as', 'chief', 'medical', 'officer', ',', 'chief', 'scientific', 'officer', 'and', 'senior', 'vice', 'president', ',', 'oncology', 'of', 'Flatiron', 'Health', '.'], ['READ', 'MORE', 'Amy', 'Abernethy', 'M.D.', ',', 'PhDChief', 'Medical', 'Officer', ',', 'Chief', 'Scientific', 'Officer', ',', 'Senior', 'Vice', 'President', ',', 'Flatiron', 'Health', 'Bill', 'George', 'is', 'an', 'American', 'businessman', 'and', 'academic', '.'], ['He', 'is', 'professor', 'of', 'Management', 'Practice', 'and', 'a', 'Henry', 'B.', 'Arthur', 'Fellow', 'of', 'Ethics', ',', 'at', 'Harvard', 'Business', 'School', '.'], ['READ', 'MORE', 'Bill', 'GeorgeSenior', 'Fellow', ',', 'Harvard', 'Business', 'School', 'and', 'Former', 'Chairman', 'and', 'CEO', ',', 'Medtronic', 'Dr.', 'Gottlieb', 'is', 'the', '23rd', 'commissioner', 'of', 'the', 'Food', 'and', 'Drug', 'Administration', '.'], ['READ', 'MORE', 'Scott', 'Gottlieb', ',', 'M.D.Commissioner', 'of', 'Food', 'and', 'Drugs', ',', 'U.S.', 'FDA', 'Fred', 'Hassan', 'is', 'a', 'special', 'limited', 'partner', 'and', 'managing', 'd ...

# %%
#POS TAGGED WORD LIST (LIST OF PAIRS) FOR TEXTS
print(pos_list)
# Out:
# [[('show', 'NN'), ('chapters', 'NNS'), ('Closing', 'NNP'), ('Bell', 'NNP'), ('Exchange', 'NNP'), (':', ':'), ('Dow', 'NNP'), ('25k', 'CD'), ('for', 'IN'), ('Christmas', 'NNP'), ('?', '.')], [('Traders', 'NNS'), ('weigh', 'VBP'), ('in', 'IN'), ('10', 'CD'), ('Hours', 'NNP'), ('Ago', 'NNP'), ('|', 'VBD'), ('04:04', 'CD'), ('Investors', 'NNS'), ('could', 'MD'), ('have', 'VB'), ('a', 'DT'), ('happy', 'JJ'), ('holiday', 'NN'), ('season', 'NN'), ('this', 'DT'), ('year', 'NN'), (',', ','), ('with', 'IN'), ('the', 'DT'), ('Dow', 'NNP'), ('Jones', 'NNP'), ('industrial', 'JJ'), ('average', 'NN'), ('possibly', 'RB'), ('hitting', 'VBG'), ('25,000', 'CD'), ('by', 'IN'), ('Christmas', 'NNP'), (',', ','), ('two', 'CD'), ('experts', 'NNS'), ('told', 'VBD'), ('CNBC', 'NNP'), ('on', 'IN'), ('Thursday', 'NNP'), ('.', '.')], [('With', 'IN'), ('Friday', 'NNP'), ('being', 'VBG'), ('the', 'DT'), ('last', 'JJ'), ('trading', 'NN'), ('day', 'NN'), ('before', 'IN'), ('the', 'DT'), ('holiday', 'NN'), (',', ','), ('that', 'WDT'), ('would', 'MD'), ('mean', 'VB'), ('a', 'DT'), ('217.71', 'CD'), ('move', 'NN'), ('higher', 'JJR'), ('in', 'IN'), ('one', 'CD'), ('day', 'NN'), ('.', '.')], [('Chris', 'NNP'), ('Cordaro', 'NNP'), (',', ','), ('chief', 'JJ'), ('investment', 'NN'), ('officer', 'NN'), ('at', 'IN'), ('RegentAtlantic', 'NNP'), (',', ','), ('thinks', 'VBZ'), ('it', 'PRP'), ('could', 'MD'), ('happen', 'VB'), ('thanks', 'NNS'), ('to', 'TO'), ('the', 'DT'), ('anticipation', 'NN'), ('of', 'IN'), ('tax', 'NN'), ('reform', 'NN'), (',', ','), ('which', 'WDT'), ('has', 'VBZ'), ('now', 'RB'), ('passed', 'VBN'), ('Congress', 'NNP'), ('and', 'CC'), ('is', 'VBZ'), ('awaiting', 'VBG'), ('President', 'NNP'), ('Donald', 'NNP'), ('Trump', 'NNP'), ("'s", 'POS'), ('signature', 'NN'), ('.', '.')], [('``', '``'), ('As', 'IN'), ('this', 'DT'), ('sinks', 'VBZ'), ('in', 'IN'), (',', ','), ('I', 'PRP'), ('think', 'VBP'), ('it', 'PRP'), ("'s", 'VBZ'), ('got', 'VBD'), ('more', 'RBR'), ('legs', 'NNS'), ('.', '.')], [('So', 'RB'), ('maybe', 'RB'), ('we', 'PRP'), ('hit', 'VBP'), ('25', 'CD'), ('[', 'JJ'), (',000', 'CD'), (']', 'NN'), ('by', 'IN'), ('Dec.', 'NNP'), ('25', 'CD'), ('for', 'IN'), ('a', 'DT'), ('Christmas', 'NNP'), ('present', 'NN'), (',', ','), ("''", "''"), ('he', 'PRP'), ('said', 'VBD'), ('in', 'IN'), ('an', 'DT'), ('interview', 'NN'), ('with', 'IN'), ('``', '``'), ('Closing', 'NNP'), ('Bell', 'NNP'), ('.', '.'), ("''", "''")], [('Brendan', 'NNP'), ('McDermid', 'NNP'), ('|', 'NNP'), ('Reuters', 'NNP'), ('Traders', 'NNP'), ('work', 'NN'), ('on', 'IN'), ('the', 'DT'), ('floor', 'NN'), ('of', 'IN'), ('the', 'DT'), ('New', 'NNP'), ('York', 'NNP'), ('Stock', 'NNP'), ('Exchange', 'NNP'), ('(', '('), ('NYSE', 'NNP'), (')', ')'), ('in', 'IN'), ('New', 'NNP'), ('York', 'NNP'), (',', ','), ('U.S.', 'NNP'), (',', ','), ('November', 'NNP'), ('30', 'CD'), (',', ','), ('2017', 'CD'), ('.', '.')], [('Stocks', 'NNS'), ('ended', 'VBD'), ('higher', 'RBR'), ('Thursday', 'NNP'), ('after', 'IN'), ('some', 'DT'), ('companies', 'NNS'), ('announced', 'VBD'), ('they', 'PRP'), ('would', 'MD'), ('increase', 'VB'), ('wages', 'NNS'), ('and', 'CC'), ('spend', 'VB'), ('on', 'IN'), ('new', 'JJ'), ('construction', 'NN'), ('thanks', 'NNS'), ('to', 'TO'), ('the', 'DT'), ('savings', 'NNS'), ('from', 'IN'), ('a', 'DT'), ('lower', 'JJR'), ('corporate', 'JJ'), ('tax', 'NN'), ('rate', 'NN'), ('.', '.')], [('The', 'DT'), ('GOP', 'NNP'), ('tax', 'NN'), ('bill', 'NN'), ('sets', 'VBZ'), ('the', 'DT'), ('rate', 'NN'), ('at', 'IN'), ('21', 'CD'), ('percent', 'NN'), (',', ','), ('down', 'RB'), ('from', 'IN'), ('the', 'DT'), ('current', 'JJ'), ('35', 'CD'), ('percent', 'NN'), ('.', '.')], [('Both', 'DT'), ('financials', 'NNS'), ('and', 'CC'), ('energy', 'NN'), (',', ','), ('which', 'WDT'), ('are', 'VBP'), ('among', 'IN'), ('the', 'DT'), ('sectors', 'NNS'), ('expected', 'VBD'), ('to', 'TO'), ('benefit', 'VB'), ('from', 'IN'), ('tax', 'NN'), ('reform', 'NN'), (',', ','), ('led', 'VBD'), ('the', 'DT'), ('rally', 'NN' ...

# %%
#CHUNK NER TREE LIST FOR TEXTS
print(chunk_list)
# Out:
# [Tree('S', [('show', 'NN'), ('chapters', 'NNS'), ('Closing', 'NNP'), Tree('ORGANIZATION', [('Bell', 'NNP'), ('Exchange', 'NNP')]), (':', ':'), ('Dow', 'NNP'), ('25k', 'CD'), ('for', 'IN'), Tree('PERSON', [('Christmas', 'NNP')]), ('?', '.')]), Tree('S', [('Traders', 'NNS'), ('weigh', 'VBP'), ('in', 'IN'), ('10', 'CD'), Tree('ORGANIZATION', [('Hours', 'NNP'), ('Ago', 'NNP')]), ('|', 'VBD'), ('04:04', 'CD'), ('Investors', 'NNS'), ('could', 'MD'), ('have', 'VB'), ('a', 'DT'), ('happy', 'JJ'), ('holiday', 'NN'), ('season', 'NN'), ('this', 'DT'), ('year', 'NN'), (',', ','), ('with', 'IN'), ('the', 'DT'), Tree('ORGANIZATION', [('Dow', 'NNP'), ('Jones', 'NNP')]), ('industrial', 'JJ'), ('average', 'NN'), ('possibly', 'RB'), ('hitting', 'VBG'), ('25,000', 'CD'), ('by', 'IN'), Tree('PERSON', [('Christmas', 'NNP')]), (',', ','), ('two', 'CD'), ('experts', 'NNS'), ('told', 'VBD'), Tree('ORGANIZATION', [('CNBC', 'NNP')]), ('on', 'IN'), ('Thursday', 'NNP'), ('.', '.')]), Tree('S', [('With', 'IN'), ('Friday', 'NNP'), ('being', 'VBG'), ('the', 'DT'), ('last', 'JJ'), ('trading', 'NN'), ('day', 'NN'), ('before', 'IN'), ('the', 'DT'), ('holiday', 'NN'), (',', ','), ('that', 'WDT'), ('would', 'MD'), ('mean', 'VB'), ('a', 'DT'), ('217.71', 'CD'), ('move', 'NN'), ('higher', 'JJR'), ('in', 'IN'), ('one', 'CD'), ('day', 'NN'), ('.', '.')]), Tree('S', [Tree('PERSON', [('Chris', 'NNP')]), Tree('ORGANIZATION', [('Cordaro', 'NNP')]), (',', ','), ('chief', 'JJ'), ('investment', 'NN'), ('officer', 'NN'), ('at', 'IN'), Tree('ORGANIZATION', [('RegentAtlantic', 'NNP')]), (',', ','), ('thinks', 'VBZ'), ('it', 'PRP'), ('could', 'MD'), ('happen', 'VB'), ('thanks', 'NNS'), ('to', 'TO'), ('the', 'DT'), ('anticipation', 'NN'), ('of', 'IN'), ('tax', 'NN'), ('reform', 'NN'), (',', ','), ('which', 'WDT'), ('has', 'VBZ'), ('now', 'RB'), ('passed', 'VBN'), Tree('ORGANIZATION', [('Congress', 'NNP')]), ('and', 'CC'), ('is', 'VBZ'), ('awaiting', 'VBG'), ('President', 'NNP'), Tree('PERSON', [('Donald', 'NNP'), ('Trump', 'NNP')]), ("'s", 'POS'), ('signature', 'NN'), ('.', '.')]), Tree('S', [('``', '``'), ('As', 'IN'), ('this', 'DT'), ('sinks', 'VBZ'), ('in', 'IN'), (',', ','), ('I', 'PRP'), ('think', 'VBP'), ('it', 'PRP'), ("'s", 'VBZ'), ('got', 'VBD'), ('more', 'RBR'), ('legs', 'NNS'), ('.', '.')]), Tree('S', [('So', 'RB'), ('maybe', 'RB'), ('we', 'PRP'), ('hit', 'VBP'), ('25', 'CD'), ('[', 'JJ'), (',000', 'CD'), (']', 'NN'), ('by', 'IN'), ('Dec.', 'NNP'), ('25', 'CD'), ('for', 'IN'), ('a', 'DT'), ('Christmas', 'NNP'), ('present', 'NN'), (',', ','), ("''", "''"), ('he', 'PRP'), ('said', 'VBD'), ('in', 'IN'), ('an', 'DT'), ('interview', 'NN'), ('with', 'IN'), ('``', '``'), ('Closing', 'NNP'), ('Bell', 'NNP'), ('.', '.'), ("''", "''")]), Tree('S', [Tree('PERSON', [('Brendan', 'NNP')]), Tree('ORGANIZATION', [('McDermid', 'NNP')]), ('|', 'NNP'), ('Reuters', 'NNP'), ('Traders', 'NNP'), ('work', 'NN'), ('on', 'IN'), ('the', 'DT'), ('floor', 'NN'), ('of', 'IN'), ('the', 'DT'), Tree('GPE', [('New', 'NNP'), ('York', 'NNP')]), ('Stock', 'NNP'), ('Exchange', 'NNP'), ('(', '('), Tree('ORGANIZATION', [('NYSE', 'NNP')]), (')', ')'), ('in', 'IN'), Tree('GPE', [('New', 'NNP'), ('York', 'NNP')]), (',', ','), Tree('GPE', [('U.S.', 'NNP')]), (',', ','), ('November', 'NNP'), ('30', 'CD'), (',', ','), ('2017', 'CD'), ('.', '.')]), Tree('S', [('Stocks', 'NNS'), ('ended', 'VBD'), ('higher', 'RBR'), ('Thursday', 'NNP'), ('after', 'IN'), ('some', 'DT'), ('companies', 'NNS'), ('announced', 'VBD'), ('they', 'PRP'), ('would', 'MD'), ('increase', 'VB'), ('wages', 'NNS'), ('and', 'CC'), ('spend', 'VB'), ('on', 'IN'), ('new', 'JJ'), ('construction', 'NN'), ('thanks', 'NNS'), ('to', 'TO'), ('the', 'DT'), ('savings', 'NNS'), ('from', 'IN'), ('a', 'DT'), ('lower', 'JJR'), ('corporate', 'JJ'), ('tax', 'NN'), ('rate', 'NN'), ('.', '.')]), Tree('S', [('The', 'DT'), Tree('ORGANIZATION', [('GOP', 'NNP')]), ('tax', 'NN'), ('bill', 'NN'), ('sets', 'VBZ'), ('the', 'DT'), ('rate', 'NN'), ('at', 'IN'), ('21', 'CD'), ( ...

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0} IS A SAMPLE POLARITY SCORE RESULT
analyser = SentimentIntensityAnalyzer()

def print_sentiment_scores(sentence):
    snt = analyser.polarity_scores(sentence)
    print("{:-<40} {}".format(sentence, str(snt)))
    
#PRINT THE SENTIMENT SCORES PER SENTENCE IN THE TEXTS (FOR ACCURACY VERIFICATION AND REFERENCE)
for s in sent_list:
    print_sentiment_scores(s)
    #PRINT KEY INDICATORS FOR OVERALL SENTIMENT POLARITY IMPACT
    if (analyser.polarity_scores(s)['pos']/2) > analyser.polarity_scores(s)['neg']:
        print("POSITIVE!")
    if (analyser.polarity_scores(s)['pos']/2) < analyser.polarity_scores(s)['neg']:
        print("NEGATIVE!")
    if analyser.polarity_scores(s)['pos'] == analyser.polarity_scores(s)['neg']:
        print("NEUTRAL")
# Out:
# ABOUT
# SPEAKERS
# AGENDA
# ADVISORY BOARD
# VENUE
# SPONSORS
# CONTACT
# About
# How innovators and investors are working with patients and providers to develop dynamic new solutions and create healthy returns. {'neg': 0.0, 'neu': 0.725, 'pos': 0.275, 'compound': 0.7964}
# POSITIVE!
# CNBC presents a one-day event at NYC’s Roosevelt Hotel that brings together top health care investors, CEOs and technologists to explore the innovations that will drive better outcomes, financially and clinically. {'neg': 0.0, 'neu': 0.774, 'pos': 0.226, 'compound': 0.7845}
# POSITIVE!
# Every health care company seeks to scale the best technology and develop profitable ways to cover the massive cost of research and development, investors are looking for actionable intelligence on who’s breaking through, and patients are hungry for affordable and effective care. {'neg': 0.0, 'neu': 0.646, 'pos': 0.354, 'compound': 0.9623}
# POSITIVE!
# Healthy Returns is a convening of leaders who are improving patient outcomes, maximizing innovation, building great new companies and reinventing incumbents. {'neg': 0.0, 'neu': 0.567, 'pos': 0.433, 'compound': 0.9042}
# POSITIVE!
# Led by CNBC’s anchors and reporters and with input from a world-class advisory board, Healthy Returns will hone in on groundbreaking ideas that will transform the health care industry, cutting through the noise and weeding out the "sales pitch." {'neg': 0.035, 'neu': 0.825, 'pos': 0.139, 'compound': 0.6597}
# POSITIVE!
# Attendees should expect to walk away with smart strategies and actionable insights from people who are shaping the industry, including:
# • Investment ideas and intelligence from the biggest and best health care hedge funds, venture capitalists and portfolio managers. {'neg': 0.0, 'neu': 0.72, 'pos': 0.28, 'compound': 0.9217}
# POSITIVE!
# • Strategic perspective from top health care CEOs. {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.6124}
# POSITIVE!
# • An early, inside look at groundbreaking, transformative innovations. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# • Unique networking opportunities to connect with leaders in multiple disciplines – investors, executives, entrepreneurs and innovators. {'neg': 0.0, 'neu': 0.843, 'pos': 0.157, 'compound': 0.3818}
# POSITIVE!
# Who should attend:
# Health care investors, VCs, C-Suite executives from the biotech, pharma, health care and life sciences industries, health care IT BDMs. {'neg': 0.0, 'neu': 0.676, 'pos': 0.324, 'compound': 0.8625}
# POSITIVE!
# Speakers
# More speakers will be announced soon. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# Tap or click a card to reveal more information:
# Amy Abernethy M.D., PhD, serves as chief medical officer, chief scientific officer and senior vice president, oncology of Flatiron Health. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# READ MORE
# Amy Abernethy M.D., PhDChief Medical Officer, Chief Scientific Officer, Senior Vice President, Flatiron Health
# Bill George is an American businessman and academic. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# He is professor of Management Practice and a Henry B. Arthur Fellow of Ethics, at Harvard Business School. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# READ MORE
# Bill GeorgeSenior Fellow, Harvard Business School and Former Chairman and CEO, Medtronic
# Dr. Gottlieb is the 23rd commissioner of the Food and Drug Administration. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# READ MORE
# Scott Gottlieb, M.D.Commissioner of Food and Drugs, U.S. FDA
# Fred Hassan is a special limited partner and managing director with the private equity firm, Warburg Pincus and chairman of Caret Group. {'neg': 0.055, 'neu': 0.867, 'pos': 0.078, 'compound': 0.2023}
# NEGATIVE!
# READ MORE
# Fred HassanSpecial Limited Partner, Warburg Pincus and Chairman, Caret Group
# Leonard S. Schleifer, M.D., PhD, is the founder, president and chief executive officer of Regeneron Pharmaceuticals. {'neg': 0.095, 'neu': 0.905, 'pos': 0.0, 'compound': -0.426}
# NEGATIVE!
# READ MORE
# Leonard S. Schleifer, M.D., PhD
# Founder, President and CEO, Regeneron Pharmaceuticals
# Agenda
# Agenda coming soon
# Advisory Board
# Tap or click a card to reveal more information:
# Amy Abernethy M.D., PhD, serves as chief medical officer, chief scientific officer and senior vice president, oncology of Flatiron Health. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# READ MORE
# Amy Abernethy M.D., PhD
# Chief Medical Officer, Chief Scientific Officer, Senior Vice President, Flatiron Health
# Dr. Coles is the chairman and chief executive officer of Yumanity Therapeutics, a biotechnology company. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# He also serves as chairman and chief executive officer of TRATE Enterprises LLC. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# READ MORE
# Tony Coles, M.D.-------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# Chairman and CEO, Yumanity Therapeutics
# Dr. Cosgrove is president and chief executive officer of Cleveland Clinic, presiding over an $8 billion health-care system. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# READ MORE
# Delos M. Cosgrove, M.D.------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# President and CEO, Cleveland Clinic
# Dr. Kenneth L. Davis, is president and chief executive officer
# of the Mount Sinai Health System in New York City, one of the nation's largest integrated health systems. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# READ MORE
# Kenneth Davis, M.D.----------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# President and CEO, Mount Sinai Health System
# Dr. Sue Desmond-Hellmann is a physician, scientist and philanthropist and is currently the chief executive officer of the Bill & Melinda Gates Foundation. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# READ MORE
# Sue Desmond-Hellmann
# CEO, Bill & Melinda Gates Foundation
# Esther Dyson is chairman of EDventure Holdings. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# Her primary activity is investing in and nurturing start-ups, with a recent focus on health care, human capital and aerospace. {'neg': 0.0, 'neu': 0.733, 'pos': 0.267, 'compound': 0.7351}
# POSITIVE!
# READ MORE
# Esther Dyson
# Chairman, EDventure Holdings
# Bill George is an American businessman and academic. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# He is professor of Management Practice and a Henry B. Arthur Fellow of Ethics at Harvard Business School. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# READ MORE
# Bill GeorgeSenior Fellow, Harvard Business School and Former Chairman and CEO, Medtronic
# Dr. Laurie H. Glimcher, president and chief executive officer of Dana-Farber Cancer Institute, is also chief executive officer of Dana-Farber/Partners CancerCare. {'neg': 0.115, 'neu': 0.885, 'pos': 0.0, 'compound': -0.6597}
# NEGATIVE!
# READ MORE
# Laurie Glimcher, M.D.--------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# President and CEO, Dana-Farber Cancer Institute
# Fred Hassan is a special limited partner and managing director with the private equity firm, Warburg Pincus and chairman of Caret Group. {'neg': 0.191, 'neu': 0.727, 'pos': 0.082, 'compound': -0.5574}
# NEGATIVE!
# READ MORE
# Fred Hassan
# Special Limited Partner, Warburg Pincus and Chairman, Caret Group
# Jessica Mega is the chief medical officer of Verily. {'neg': 0.074, 'neu': 0.784, 'pos': 0.142, 'compound': 0.4065}
# NEGATIVE!
# She is also a cardiologist who trained and practiced at Massachusetts General Hospital and Brigham and Women’s Hospital. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# READ MORE
# Jessica Mega, M.D., M.P.H
# Chief Medical Officer, Verily
# Dr. John H. Noseworthy is president and chief executive officer
# of Mayo Clinic. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# READ MORE
# John Noseworthy, M.D.--------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# President and CEO, Mayo Clinic
# Sean Parker is the founder and president of The Parker Foundation. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# He helped to establish the Stand Up 2 Cancer and Cancer Research Institute's (CRI) Immunology Dream Team in 2012. {'neg': 0.341, 'neu': 0.581, 'pos': 0.078, 'compound': -0.8316}
# NEGATIVE!
# READ MORE
# Sean Parker
# Founder and President, The Parker Foundation
# Eric Topol is the founder and director of the Scripps Translational Science Institute and professor of Molecular Medicine at the Scripps Research Institute. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# READ MORE
# Eric Topol, M.D.-------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# Founder and Director, Scripps Translational Science Institute
# Anne Wojcicki co-founded 23andMe in 2006 after a decade in health care investing focusing on biotechnology companies. {'neg': 0.0, 'neu': 0.873, 'pos': 0.127, 'compound': 0.4939}
# POSITIVE!
# READ MORE
# Anne Wojcicki
# Co-Founder and CEO, 23andMe
# Venue
# The Roosevelt Hotel
# The Roosevelt Hotel
# 45 E 45th Street
# New York, NY 10017
# There is a special CNBC room rate of $219 per night, plus tax. {'neg': 0.0, 'neu': 0.924, 'pos': 0.076, 'compound': 0.4019}
# POSITIVE!
# To reserve a room with this rate, please call the Roosevelt Hotel directly at 212-661-9600. {'neg': 0.0, 'neu': 0.85, 'pos': 0.15, 'compound': 0.3182}
# POSITIVE!
# Please note this special rate will be honored until February 27, 2018 or until the limited block has been filled. {'neg': 0.168, 'neu': 0.524, 'pos': 0.308, 'compound': 0.6124}
# NEGATIVE!
# Click here for hotel directions.-------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# Sponsors
# CONTACT
# Are you looking for more information? {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# Please contact the following:
# • For sponsorship opportunities, contact Alisha Hathaway
# • For speaker and editorial inquiries, contact Maneet Ahuja
# • For press and media inquiries, contact Jennifer Dauble
# • For other questions, contact healthyreturns@cnbc.com {'neg': 0.0, 'neu': 0.855, 'pos': 0.145, 'compound': 0.5994}
# POSITIVE!
# Stocks rose to record highs on Friday after some of the major financial companies in the U.S. reported strong quarterly results. {'neg': 0.0, 'neu': 0.858, 'pos': 0.142, 'compound': 0.5106}
# POSITIVE!
# The Dow Jones industrial average rose 228.46 points to close at 25,803.19, an all-time high. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# J.P. Morgan Chase was among the best-performing stocks in the index, rising 1.7 percent. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# The S&P 500 also reached a record high, climbing 0.7 percent to 2,786.24 with energy and consumer discretionary as the best-performing sectors. {'neg': 0.0, 'neu': 0.844, 'pos': 0.156, 'compound': 0.3612}
# POSITIVE!
# Energy stocks got a boost from rising oil prices. {'neg': 0.0, 'neu': 0.556, 'pos': 0.444, 'compound': 0.5859}
# POSITIVE!
# The index is also enjoying its best 10-day start to a year since 2003. {'neg': 0.0, 'neu': 0.591, 'pos': 0.409, 'compound': 0.8225}
# POSITIVE!
# In that time period, the S&P 500 is up 4.2 percent. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# It gained 5.9 percent during the first 10 days of 2003. {'neg': 0.0, 'neu': 0.794, 'pos': 0.206, 'compound': 0.3818}
# POSITIVE!
# "There is optimism in the market," but there is also uncertainty about this rally, said Cooper Abbott, chairman of Carillon Tower Advisers. {'neg': 0.122, 'neu': 0.789, 'pos': 0.089, 'compound': -0.2144}
# NEGATIVE!
# That level of uncertainty can be good for the market because it "dampens expectations." {'neg': 0.139, 'neu': 0.694, 'pos': 0.168, 'compound': 0.128}
# NEGATIVE!
# The Nasdaq composite finished 0.7 percent higher at 7,261.06. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# Amazon shares rose 2.2 percent and broke above $1,300 for the first time. {'neg': 0.168, 'neu': 0.599, 'pos': 0.234, 'compound': 0.0258}
# NEGATIVE!
# J.P. Morgan Chase, BlackRock and Wells Fargo all reported better-than-expected quarterly results. {'neg': 0.0, 'neu': 0.846, 'pos': 0.154, 'compound': 0.25}
# POSITIVE!
# Brendan McDermid | Reuters
# Traders work on the floor of the New York Stock Exchange. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# S&P 500 profits are expected to have risen 11.2 percent in the fourth quarter of last year. {'neg': 0.0, 'neu': 0.847, 'pos': 0.153, 'compound': 0.4404}
# POSITIVE!
# All 11 S&P 500 sectors, meanwhile, are expected to post increases in both earnings and revenue, according to FactSet. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# This would be the first time since 2011 that all the sectors in the S&P 500 posted sales and profit growth for the same quarter. {'neg': 0.0, 'neu': 0.807, 'pos': 0.193, 'compound': 0.6705}
# POSITIVE!
# Stocks have carried over the momentum from 2017 into the new year thus far. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# The S&P 500 and Nasdaq have closed lower only once this year, while the Dow has fallen just twice. {'neg': 0.217, 'neu': 0.783, 'pos': 0.0, 'compound': -0.5719}
# NEGATIVE!
# For 2018, the major averages are up at least 3.5 percent entering Friday's session. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# For the week, they posted gains of at least 1.6 percent. {'neg': 0.0, 'neu': 0.806, 'pos': 0.194, 'compound': 0.34}
# POSITIVE!
# The Dow outperformed the Nasdaq and S&P 500 this week, gaining 2
# percent, as Boeing shares have soared 8.9 percent. {'neg': 0.0, 'neu': 0.773, 'pos': 0.227, 'compound': 0.6124}
# POSITIVE!
# "The most important dynamic to focus on in the market is growth," said Sandip Bhagat, chief investment officer at Whittier Trust. {'neg': 0.0, 'neu': 0.685, 'pos': 0.315, 'compound': 0.8059}
# POSITIVE!
# He acknowledged that risks to the rally do exist, but added: "They pale in comparison to the economic growth we're seeing." {'neg': 0.065, 'neu': 0.793, 'pos': 0.142, 'compound': 0.431}
# POSITIVE!
# Recent data suggests the U.S. economy is picking up steam. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# The Labor Department said its Consumer Price Index excluding the volatile food and energy components rose 0.3 percent last month. {'neg': 0.0, 'neu': 0.9, 'pos': 0.1, 'compound': 0.2732}
# POSITIVE!
# That was the biggest advance in the so-called core CPI since January. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# Treasury yields ticked higher following the data release. {'neg': 0.264, 'neu': 0.566, 'pos': 0.17, 'compound': -0.25}
# NEGATIVE!
# The two-year yield broke above 2 percent for the first time since September 2008. {'neg': 0.189, 'neu': 0.811, 'pos': 0.0, 'compound': -0.4215}
# NEGATIVE!
# It traded at 2.01 percent.-------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# —Reuters contributed to this report.---- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# Getty Images
# A trader wears a DOW 24,000 hat as he works on the floor of the New York Stock Exchange, (NYSE) as the Dow Jones Industrial Average crosses 25,000 on Jan. 4ht, 2018 for the first time. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# U.S. stock index futures gave back some of their gains on Friday after the release of key inflation data. {'neg': 0.0, 'neu': 0.882, 'pos': 0.118, 'compound': 0.34}
# POSITIVE!
# Dow Jones industrial average futures traded 72 points higher; they had risen more than 100 points earlier in the session. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# S&P 500 futurews were down half a point and Nasdaq 100 futures fell 21 points. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# The Labor Department said its Consumer Price Index excluding the volatile food and energy components rose 0.3 percent last month. {'neg': 0.0, 'neu': 0.9, 'pos': 0.1, 'compound': 0.2732}
# POSITIVE!
# That was the biggest advance in the so-called core CPI since January. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# Equity futures had risen after Wells Fargo and J.P. Morgan Chase reported better-than-expected quarterly results. {'neg': 0.0, 'neu': 0.875, 'pos': 0.125, 'compound': 0.25}
# POSITIVE!
# BlackRock also posted results that beat expectations. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# On Thursday, the Dow hit an all-time high, with the index rising more than 200 points by the close. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# The state of the U.S. economy and tax reform is set to be of key importance on Friday as major U.S. banks are set to report. {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'compound': 0.3612}
# POSITIVE!
# Markets have been on the rise as of late, after President Donald Trump signed a bill in December to slash the corporate tax rate from 35 percent to 21 percent. {'neg': 0.07, 'neu': 0.93, 'pos': 0.0, 'compound': -0.2732}
# NEGATIVE!
# Meantime, investors will keep a close eye on bond markets, after investors fretted over the risk of China halting its Treasury bond purchases. {'neg': 0.088, 'neu': 0.837, 'pos': 0.075, 'compound': -0.0772}
# NEGATIVE!
# Vote
# Vote to see results
# Total Votes:
# Not a Scientific Survey. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# Results may not total 100% due to rounding. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# On Wednesday, Bloomberg News reported, citing people familiar with the matter, that officials in Beijing had recommended that China's government lowers — or even potentially ceases — its buying of U.S. sovereign debt. {'neg': 0.118, 'neu': 0.796, 'pos': 0.086, 'compound': -0.2732}
# NEGATIVE!
# However, China's currency regulator has since refuted the report. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# On the U.S. central bank front, Boston Fed President Eric Rosengren is expected to be in California, where he's set to give a keynote address at the Money, Models, and Digital Innovation conference in San Diego. {'neg': 0.0, 'neu': 0.929, 'pos': 0.071, 'compound': 0.3818}
# POSITIVE!
# Meantime, Philadelphia Fed President Patrick Harker is expected to be present at the Central Bucks Chamber of Commerce Economic Luncheon in Pennsylvania. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# Overseas, coalition party leaders in Germany have reached a breakthrough in talks to form a new government. {'neg': 0.0, 'neu': 0.76, 'pos': 0.24, 'compound': 0.4767}
# POSITIVE!
# German Chancellor Angela Merkel had entered into talks with a rival party in a last-ditch effort to form a coalition government. {'neg': 0.0, 'neu': 0.863, 'pos': 0.137, 'compound': 0.4019}
# POSITIVE!
# This comes after months of political uncertainty. {'neg': 0.286, 'neu': 0.714, 'pos': 0.0, 'compound': -0.34}
# NEGATIVE!
# —Reuters contributed to this report.---- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# Oleg Popov | Reuters
# The stock market will enjoy a "Made in America" boom this year thanks to a slew of policies spearheaded by the Trump administration, according to a Wall Street investment bank. {'neg': 0.0, 'neu': 0.821, 'pos': 0.179, 'compound': 0.7269}
# POSITIVE!
# Some of the nation's largest industrial and steel companies will rally under President Donald Trump's focus on domestic prosperity, spelling even more upside for investors, according to Jefferies. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# With the U.S. thinking about leaving NAFTA, "new tax incentives to repatriate profits in place and the dollar weak, the ingredients for a domestic investment boom are in place," analyst Sean Darby wrote Thursday. {'neg': 0.076, 'neu': 0.787, 'pos': 0.136, 'compound': 0.3182}
# NEGATIVE!
# "While the corporate sector is obviously euphoric over the tax changes, it is not often highlighted that it has improved U.S.'s competitive position." {'neg': 0.0, 'neu': 0.69, 'pos': 0.31, 'compound': 0.8402}
# POSITIVE!
# show chapters
# These NAFTA-sensitive stocks are moving on trade talks
# 7:58
# AM ET Thu, 11 Jan 2018 |
# 02:16
# Trump and Republican lawmakers clinched a major legislative victory by passing the Tax Cuts and Jobs Act in late 2017, reducing the corporate tax rate to 21 percent and offering new incentives for companies to repatriate profits. {'neg': 0.038, 'neu': 0.873, 'pos': 0.089, 'compound': 0.4588}
# POSITIVE!
# The GOP hopes that by amending the tax code the economy will surge further, and drive most investing dollars into the U.S. {'neg': 0.0, 'neu': 0.882, 'pos': 0.118, 'compound': 0.4215}
# POSITIVE!
# But even as some of the country's industrial titans catch a tax break, the fate of some of the country's most iconic trade agreements hang in the balance. {'neg': 0.0, 'neu': 0.917, 'pos': 0.083, 'compound': 0.3321}
# POSITIVE!
# Trump is currently debating U.S. participation in NAFTA, the iconic 24-year-old trade pact with Canada and Mexico. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# Should the U.S. pull out of the agreement, incentives to "off-shore" factories could diminish. {'neg': 0.0, 'neu': 0.686, 'pos': 0.314, 'compound': 0.6705}
# POSITIVE!
# "The NAFTA trade agreement encouraged 'off-shoring' or the placement of U.S. manufacturing in its neighbors due to better labor laws, cheaper exchange rates and/or lower wages," added Darby. {'neg': 0.063, 'neu': 0.69, 'pos': 0.247, 'compound': 0.7506}
# POSITIVE!
# "Coincidentally, next Tuesday, the U.S. Department of Commerce is expected to provide formal recommendations to the President regarding possible action to combat U.S. steel imports on national security grounds." {'neg': 0.075, 'neu': 0.849, 'pos': 0.075, 'compound': 0.0}
# NEGATIVE!
# NEUTRAL
# Such decisions by the Trump administration are likely already having an effect on the business world. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# The Dow Jones industrial average added more than 150 points to claim another all-time high Thursday while both the S&P 500 and the Nasdaq hit records. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# The gains in the Dow have largely stemmed from industrial giants Boeing, Chevron and Caterpillar, seen as key beneficiaries from the tax changes. {'neg': 0.0, 'neu': 0.802, 'pos': 0.198, 'compound': 0.6369}
# POSITIVE!
# The materials sector, including the nation's largest steel manufacturers, should also benefit from more protective policies, said Darby, even as factory activity climbs. {'neg': 0.0, 'neu': 0.88, 'pos': 0.12, 'compound': 0.4588}
# POSITIVE!
# "The bottom line is that the backdrop for the U.S. materials sector is improving," wrote Darby. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# "The cocktail of tax reform, NAFTA, steel tariffs, and booming investment intentions comes at a time when the ISM manufacturing index is surging." {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# NEUTRAL
# Names like United States Steel, Commercial Metals and Steel Dynamics are the "best positioned" to benefit from steel tariffs, Darby said, all of which have buy ratings from the investment bank. {'neg': 0.0, 'neu': 0.64, 'pos': 0.36, 'compound': 0.9274}
# POSITIVE!
# The companies were up 0.75 percent, 2.1 percent, and 1.7 percent respectively during Thursday trading. {'neg': 0.0, 'neu': 0.854, 'pos': 0.146, 'compound': 0.34}
# POSITIVE!
# Disclaimer
# WATCH: US playing 'Russian roulette' with Canada-NAFTA talks
# show chapters
# US playing 'Russian roulette' in Canada-NAFTA talks: Former US Ambassador to Canada
# 7:22
# AM ET Thu, 11 Jan 2018 |
# 02:39 {'neg': 0.0, 'neu': 0.89, 'pos': 0.11, 'compound': 0.3818}
# POSITIVE!

# %%
#PRINT THE INDIVIDUAL AVERAGE SENTIMENT SCORES FOR EACH ARTICLE REFERENCED
pos_count = 0.00
neg_count = 0.00

for text in texts:
    print(analyser.polarity_scores(text))
    if analyser.polarity_scores(text)['compound'] > .85:
        print("STRONG POSITIVE SENTIMENT")
        pos_count + 1.25
    if analyser.polarity_scores(text)['compound'] > .5 and analyser.polarity_scores(text)['compound'] < .85:
        print("WEAK POSITIVE SENTIMENT")
        pos_count + 1
    if analyser.polarity_scores(text)['compound'] > 0 and analyser.polarity_scores(text)['compound'] < .5:
        print("NEUTRAL SENTIMENT")
    if analyser.polarity_scores(text)['compound'] > -.5 and analyser.polarity_scores(text)['compound'] < 0:
        print("WEAK NEGATIVE SENTIMENT")
        neg_count + 1
    if analyser.polarity_scores(text)['compound'] < -.5:
        print("STRONG NEGATIVE SENTIMENT")
        neg_count + 1.25
        
print("\n")
        
if pos_count > neg_count:
    print("CURRENT OVERALL STOCK SENTIMENT FOR " + symbol + " IS POSITIVE!")
if pos_count < neg_count:
    print("CURRENT OVERALL STOCK SENTIMENT FOR " + symbol + " IS NEGATIVE!")
if pos_count == neg_count:
    print("CURRENT OVERALL STOCK SENTIMENT FOR " + symbol + " IS NEUTRAL.")
# Out:
# {'neg': 0.03, 'neu': 0.858, 'pos': 0.112, 'compound': 0.9979}
# STRONG POSITIVE SENTIMENT
# {'neg': 0.051, 'neu': 0.822, 'pos': 0.127, 'compound': 0.9843}
# STRONG POSITIVE SENTIMENT
# {'neg': 0.025, 'neu': 0.919, 'pos': 0.055, 'compound': 0.8591}
# STRONG POSITIVE SENTIMENT
# {'neg': 0.017, 'neu': 0.847, 'pos': 0.135, 'compound': 0.9958}
# STRONG POSITIVE SENTIMENT
#
#
# CURRENT OVERALL STOCK SENTIMENT FOR .DJI IS NEUTRAL.

# %% [markdown]
# Future improvements would be to create a custom trained neural network. The Vader analysis does a great job in detection and analysis, but it is mainly intended for social media analysis. In concern to news articles, especially those on stocks, a large majority of the text lacks emotion or obvious sentiment (creating the large neutral score during analysis), but a "modified" type of sentiment can be better gathered if we were to train the neural network sentiment analyzer with stock terminology (and the accompanying general sentiment).
